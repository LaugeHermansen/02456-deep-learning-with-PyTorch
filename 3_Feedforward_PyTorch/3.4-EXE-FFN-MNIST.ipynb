# %% [markdown]
# # Credits
# > This code is a slight modification to a translation (TensorFlow --> PyTorch) of a previous version of the [02456](http://kurser.dtu.dk/course/02456) course material.
# > [Original repo link (TensorFlow)](https://github.com/DeepLearningDTU/02456-deep-learning).
# > [Translated repo link (PyTorch)](https://github.com/munkai/pytorch-tutorial/tree/master/2_intermediate).

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init

# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

from torch.nn.parameter import Parameter
from torchvision.datasets import MNIST

# %% [markdown]
# # MNIST dataset
# MNIST is a dataset that is often used for benchmarking. The MNIST dataset consists of 70,000 images of handwritten digits from 0-9. The dataset is split into a 50,000 images training set, 10,000 images validation set and 10,000 images test set. The images are 28x28 pixels, where each pixel represents a normalised value between 0-255 (0=black and 255=white).
#
# ![MNIST.Exampel](https://github.com/LaugeHermansen/02456-deep-learning-with-PyTorch/blob/master/static_files/mnist.png?raw=1)
#
#
# ## Primer
# We use a feedforward neural network to classify the 28x28 mnist images. `num_features` is therefore $28 * 28=784$, i.e. we represent each image as a vector. The ordering of the pixels in the vector does not matter, so we could permutate all images using the same permutation and still get the same performance. (You are of course encouraged to try this using ``numpy.random.permutation`` to get a random permutation. This task is therefore called the _permutation invariant_ MNIST. Obviously this throws away a lot of structure in the data. In the next module we'll fix this with the convolutional neural network wich encodes prior knowledgde about data that has either spatial or temporal structure.

# %% [markdown]
# ## MNIST
# First let's load the MNIST dataset and plot a few examples:

# %%
mnist_trainset = MNIST("./temp/", train=True, download=True)
mnist_testset = MNIST("./temp/", train=False, download=True)

# %%
# To speed up training we'll only work on a subset of the data
x_train = mnist_trainset.data[:1000].view(-1, 784).float().div_(255)
targets_train = mnist_trainset.targets[:1000]

x_valid = mnist_trainset.data[1000:1500].view(-1, 784).float().div_(255)
targets_valid = mnist_trainset.targets[1000:1500]

x_test = mnist_testset.data[:500].view(-1, 784).float().div_(255)
targets_test = mnist_testset.targets[:500]

print("Information on dataset")
print("x_train", x_train.shape)
print("targets_train", targets_train.shape)
print("x_valid", x_valid.shape)
print("targets_valid", targets_valid.shape)
print("x_test", x_test.shape)
print("targets_test", targets_test.shape)
# Out:
# Information on dataset
# x_train torch.Size([1000, 784])
# targets_train torch.Size([1000])
# x_valid torch.Size([500, 784])
# targets_valid torch.Size([500])
# x_test torch.Size([500, 784])
# targets_test torch.Size([500])

# %%
# plot a few MNIST examples
idx, dim, classes = 0, 28, 10
# create empty canvas
canvas = np.zeros((dim*classes, classes*dim))

# fill with tensors
for i in range(classes):
    for j in range(classes):
        canvas[i*dim:(i+1)*dim, j*dim:(j+1)*dim] = x_train[idx].reshape((dim, dim))
        idx += 1

# visualize matrix of tensors as gray scale image
plt.figure(figsize=(4, 4))
plt.axis('off')
plt.imshow(canvas, cmap='gray')
plt.title('MNIST handwritten digits')
plt.show()

# %% [markdown]
# ## Model
#
# One of the large challenges in deep learning is the amount of hyperparameters that needs to be selected, and the lack of a good principled way of selecting them.
# Hyperparameters can be found by experience (guessing) or some search procedure (often quite slow).
# Random search is easy to implement and performs decent: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf .
# More advanced search procedures include [Spearmint](https://github.com/JasperSnoek/spearmint) and many others.
#
# **In practice a lot of trial and error is almost always involved.** This can be frustrating and time consuming, but the best thing to do is to think as a scientist, and go about it in a ordered manner --> monitor as much as you can, take notes, and be deliberate!
#
# Below are some guidelines that you can use as a starting point to some of the most important hyperparameters.
# (*regularization* is also very important, but will be covered later.)
#
#
# ### Ballpark estimates of hyperparameters
# __Number of hidden units and network structure:__
# You'll have to experiment. One rarely goes below 512 units for feedforward networks (unless your are training on CPU...).
# There's some research into stochastic depth networks: https://arxiv.org/pdf/1603.09382v2.pdf, but in general this is trial and error.
#
# __Parameter initialization:__
# Parameter initialization is extremely important.
# PyTorch has a lot of different initializers, check the [PyTorch API](http://pytorch.org/docs/master/nn.html#torch-nn-init). Often used initializer are
# 1. Kaiming He
# 2. Xavier Glorot
# 3. Uniform or Normal with small scale (0.1 - 0.01)
# 4. Orthogonal (this usually works very well for RNNs)
#
# Bias is nearly always initialized to zero using the [torch.nn.init.constant(tensor, val)](http://pytorch.org/docs/master/nn.html#torch.nn.init.constant)
#
# __Mini-batch size:__
# Usually people use 16-256. Bigger is not allways better. With smaller mini-batch size you get more updates and your model might converge faster. Also small batch sizes use less memory, which means you can train a model with more parameters.
#
# __Nonlinearity:__ [The most commonly used nonliearities are](http://pytorch.org/docs/master/nn.html#non-linear-activations)
# 1. ReLU
# 2. Leaky ReLU
# 3. ELU
# 3. Sigmoid (rarely, if ever, used in hidden layers anymore, squashes the output to the interval [0, 1] - appropriate if the targets are binary.
# 4. Tanh is similar to the sigmoid, but squashes to [-1, 1]. Rarely used any more.
# 4. Softmax normalizes the output to 1, usrful if you have a multi-class classification problem.
#
# See the plot below.
#
# __Optimizer and learning rate:__
# 1. SGD + Momentum: learning rate 0.01 - 0.1
# 2. ADAM: learning rate 3e-4 - 1e-5
# 3. RMSPROP: somewhere between SGD and ADAM

# %%
# Illustrate different output units
x = np.linspace(-6, 6, 100)
units = {
    "ReLU": lambda x: np.maximum(0, x),
    "Leaky ReLU": lambda x: np.maximum(0, x) + 0.1 * np.minimum(0, x),
    "Elu": lambda x: (x > 0) * x + (1 - (x > 0)) * (np.exp(x) - 1),
    "Sigmoid": lambda x: (1 + np.exp(-x))**(-1),
    "tanh": lambda x: (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))
}

plt.figure(figsize=(5, 5))
[plt.plot(x, unit(x), label=unit_name, lw=2) for unit_name, unit in units.items()]
plt.legend(loc=2, fontsize=16)
plt.title('Non-linearities', fontsize=20)
plt.ylim([-2, 5])
plt.xlim([-6, 6])

# assert that all class probablities sum to one
softmax = lambda x: np.exp(x) / np.sum(np.exp(x))
print("softmax should sum to one (approxiamtely):", np.sum(softmax(x)))
# Out:
# softmax should sum to one (approxiamtely): 1.0

# %%
#Hyperparameters
num_classes = 10
num_l1 = 512
num_features = x_train.shape[1]

# define network
class Net(nn.Module):

    def __init__(self, num_features, num_hidden, num_output):
        super(Net, self).__init__()  
        # input layer
        self.W_1 = Parameter(init.xavier_normal_(torch.Tensor(num_hidden, num_features)))
        self.b_1 = Parameter(init.constant_(torch.Tensor(num_hidden), 0))
        # hidden layer
        self.W_2 = Parameter(init.xavier_normal_(torch.Tensor(num_output, num_hidden)))
        self.b_2 = Parameter(init.constant_(torch.Tensor(num_output), 0))
        # define activation function in constructor
        self.activation = torch.nn.ELU()

    def forward(self, x):
        x = F.linear(x, self.W_1, self.b_1)
        x = self.activation(x)
        x = F.linear(x, self.W_2, self.b_2)
        return x


net = Net(num_features, num_l1, num_classes)

# %%
optimizer = optim.SGD(net.parameters(), lr=0.01)
criterion = nn.CrossEntropyLoss()

# %%
# Test the forward pass with dummy data
x = np.random.normal(0, 1, (45, dim*dim)).astype('float32')

print(net(torch.from_numpy(x)).size())
# Out:
# torch.Size([45, 10])

# %% [markdown]
# # Build the training loop
#
# We train the network by calculating the gradient w.r.t the cost function and update the parameters in direction of the negative gradient.
#
#
# When training neural network you always use mini batches. Instead of calculating the average gradient using the entire dataset you approximate the gradient using a mini-batch of typically 16 to 256 samples. The paramters are updated after each mini batch. Networks converge much faster using mini batches because the parameters are updated more often.
#
# We build a loop that iterates over the training data. Remember that the parameters are updated each time ``optimizer.step()`` is called.

# %%
# we could have done this ourselves,
# but we should be aware of sklearn and its tools
from sklearn.metrics import accuracy_score

# normalize the inputs
# x_train.div_(255)
# x_valid.div_(255)
# x_test.div_(255)

# setting hyperparameters and gettings epoch sizes
batch_size = 100
num_epochs = 200
num_samples_train = x_train.shape[0]
num_batches_train = num_samples_train // batch_size
num_samples_valid = x_valid.shape[0]
num_batches_valid = num_samples_valid // batch_size

# setting up lists for handling loss/accuracy
train_acc, train_loss = [], []
valid_acc, valid_loss = [], []
test_acc, test_loss = [], []
cur_loss = 0
losses = []

get_slice = lambda i, size: range(i * size, (i + 1) * size)

for epoch in range(num_epochs):
    # Forward -> Backprob -> Update params
    ## Train
    cur_loss = 0
    net.train()
    for i in range(num_batches_train):
        optimizer.zero_grad()
        slce = get_slice(i, batch_size)
        output = net(x_train[slce])
        
        # compute gradients given loss
        target_batch = targets_train[slce]
        batch_loss = criterion(output, target_batch)
        batch_loss.backward()
        optimizer.step()
        
        cur_loss += batch_loss   
    losses.append(cur_loss / batch_size)

    net.eval()
    ### Evaluate training
    train_preds, train_targs = [], []
    for i in range(num_batches_train):
        slce = get_slice(i, batch_size)
        output = net(x_train[slce])
        
        preds = torch.max(output, 1)[1]
        
        train_targs += list(targets_train[slce].numpy())
        train_preds += list(preds.data.numpy())
    
    ### Evaluate validation
    val_preds, val_targs = [], []
    for i in range(num_batches_valid):
        slce = get_slice(i, batch_size)
        
        output = net(x_valid[slce])
        preds = torch.max(output, 1)[1]
        val_targs += list(targets_valid[slce].numpy())
        val_preds += list(preds.data.numpy())
        

    train_acc_cur = accuracy_score(train_targs, train_preds)
    valid_acc_cur = accuracy_score(val_targs, val_preds)
    
    train_acc.append(train_acc_cur)
    valid_acc.append(valid_acc_cur)
    
    if epoch % 10 == 0:
        print("Epoch %2i : Train Loss %f , Train acc %f, Valid acc %f" % (
                epoch+1, losses[-1], train_acc_cur, valid_acc_cur))

epoch = np.arange(len(train_acc))
plt.figure()
plt.plot(epoch, train_acc, 'r', epoch, valid_acc, 'b')
plt.legend(['Train Accucary','Validation Accuracy'])
plt.xlabel('Updates'), plt.ylabel('Acc')
# Out:
# Epoch  1 : Train Loss 0.222419 , Train acc 0.300000, Valid acc 0.260000
# Epoch 11 : Train Loss 0.103436 , Train acc 0.805000, Valid acc 0.758000
# Epoch 21 : Train Loss 0.072833 , Train acc 0.847000, Valid acc 0.810000
# Epoch 31 : Train Loss 0.059178 , Train acc 0.866000, Valid acc 0.822000
# Epoch 41 : Train Loss 0.051144 , Train acc 0.880000, Valid acc 0.824000
# Epoch 51 : Train Loss 0.045685 , Train acc 0.887000, Valid acc 0.836000
# Epoch 61 : Train Loss 0.041644 , Train acc 0.901000, Valid acc 0.842000
# Epoch 71 : Train Loss 0.038476 , Train acc 0.911000, Valid acc 0.844000
# Epoch 81 : Train Loss 0.035889 , Train acc 0.916000, Valid acc 0.844000
# Epoch 91 : Train Loss 0.033710 , Train acc 0.921000, Valid acc 0.846000
# Epoch 101 : Train Loss 0.031833 , Train acc 0.924000, Valid acc 0.854000
# Epoch 111 : Train Loss 0.030184 , Train acc 0.927000, Valid acc 0.858000
# Epoch 121 : Train Loss 0.028715 , Train acc 0.929000, Valid acc 0.858000
# Epoch 131 : Train Loss 0.027391 , Train acc 0.933000, Valid acc 0.858000
# Epoch 141 : Train Loss 0.026186 , Train acc 0.939000, Valid acc 0.856000
# Epoch 151 : Train Loss 0.025079 , Train acc 0.940000, Valid acc 0.854000
# Epoch 161 : Train Loss 0.024057 , Train acc 0.946000, Valid acc 0.852000
# Epoch 171 : Train Loss 0.023107 , Train acc 0.950000, Valid acc 0.856000
# Epoch 181 : Train Loss 0.022221 , Train acc 0.952000, Valid acc 0.856000
# Epoch 191 : Train Loss 0.021390 , Train acc 0.954000, Valid acc 0.856000
# (Text(0.5, 0, 'Updates'), Text(0, 0.5, 'Acc'))

# %%
class MyNet(nn.Module):
    def __init__(self, dimensions, initializer=init.xavier_normal_, batch_norm=False, lambda1=0, lambda2=0, dropout=0.0):
        super().__init__()
        self.L = len(dimensions)-1
        self.dimensions = dimensions
        self.W = nn.ParameterList([nn.Parameter(initializer(torch.Tensor(dimensions[l+1], dimensions[l]))) for l in range(self.L)])
        self.b = nn.ParameterList([nn.Parameter(init.constant_(torch.Tensor(dimensions[l+1]), 0)) for l in range(self.L)])
        self.dropout = nn.Dropout(p=dropout) if dropout > 1e-6 else lambda x: x
        self.batch_norm = nn.ModuleList([nn.BatchNorm1d(dimensions[l]) for l in range(self.L)])
        self.activation = torch.nn.ReLU()

        self.train_acc = []
        self.valid_acc = []

        self.lambda1 = lambda1
        self.lambda2 = lambda2

    def forward(self, x):
        for l in range(self.L):
            x = self.batch_norm[l](x)
            x = self.dropout(x)
            x = F.linear(x, self.W[l], self.b[l])
            x = self.activation(x)

        x = F.softmax(x, dim=1)
        return x
    
    def update_train_stats(self, train_acc, valid_acc):
        self.train_acc += train_acc
        self.valid_acc += valid_acc

    def plot_train_stats(self, plot_now=True, title=None):
        epoch = np.arange(len(self.train_acc))
        plt.figure()
        plt.plot(epoch, self.train_acc, 'r', epoch, self.valid_acc, 'b')
        plt.legend(['Train Accucary','Validation Accuracy'])
        plt.xlabel('Updates'), plt.ylabel('Acc')
        plt.ylim(0.,1.)
        if title != None: plt.title(title)
        if plot_now: plt.show()

# %%
def train_model(net, optimizer_fn, num_epochs=200, batch_size=100, x_train=x_train, targets_train=targets_train, plot_title=None):

    print("")
    print("Training model" if plot_title == None else plot_title)

    optimizer = optimizer_fn(net)

    # setting hyperparameters and gettings epoch sizes
    # batch_size = 100
    # num_epochs = 200
    num_samples_train = x_train.shape[0]
    num_batches_train = num_samples_train // batch_size
    num_samples_valid = x_valid.shape[0]
    num_batches_valid = num_samples_valid // batch_size


    # setting up lists for handling loss/accuracy
    train_acc, train_loss = [], []
    valid_acc, valid_loss = [], []
    test_acc, test_loss = [], []
    cur_loss = 0
    losses = []

    get_slice = lambda i, size: range(i * size, (i + 1) * size)

    for epoch in range(num_epochs):
        # Forward -> Backprob -> Update params
        ## Train
        cur_loss = 0
        net.train()
        for i in range(num_batches_train):
            optimizer.zero_grad()
            slce = get_slice(i, batch_size)
            output = net(x_train[slce])
            
            # compute gradients given loss
            target_batch = targets_train[slce]

            batch_loss = criterion(output, target_batch)
            
            batch_loss.backward()
            optimizer.step()
            
            cur_loss += batch_loss   
        losses.append(cur_loss / batch_size)

        net.eval()
        ### Evaluate training
        train_preds, train_targs = [], []
        for i in range(num_batches_train):
            slce = get_slice(i, batch_size)
            output = net(x_train[slce])
            
            preds = torch.max(output, 1)[1]
            
            train_targs += list(targets_train[slce].numpy())
            train_preds += list(preds.data.numpy())
        
        ### Evaluate validation
        val_preds, val_targs = [], []
        for i in range(num_batches_valid):
            slce = get_slice(i, batch_size)
            
            output = net(x_valid[slce])
            preds = torch.max(output, 1)[1]
            val_targs += list(targets_valid[slce].numpy())
            val_preds += list(preds.data.numpy())
            

        train_acc_cur = accuracy_score(train_targs, train_preds)
        valid_acc_cur = accuracy_score(val_targs, val_preds)
        
        train_acc.append(train_acc_cur)
        valid_acc.append(valid_acc_cur)
        
        if epoch % 10 == 9:
            print("Epoch %2i : Train Loss %f , Train acc %f, Valid acc %f" % (
                    epoch+1+len(net.train_acc), losses[-1], train_acc_cur, valid_acc_cur))
    
    net.update_train_stats(train_acc=train_acc, valid_acc=valid_acc)
    net.plot_train_stats(plot_now=False, title=plot_title)

# %%
layers = (num_features, 1024, 512, 256, num_classes)
num_epochs = 200

optimizerAdam = lambda lr=1e-5, weight_decay=0.: lambda net: optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
optimizerSGD = lambda lr=1e-2, momentum=0.99: lambda net: optim.SGD(net.parameters(), lr=lr, momentum=momentum)

initializers = (("He", init.kaiming_normal_), ("Xavier", init.xavier_normal_))
optimizers = (("Adam", lambda: optimizerAdam()),
               ("SGD", lambda: optimizerSGD(momentum=0.97)),
               ("SGD momentum", lambda: optimizerSGD(lr=1e-1,momentum=0.)))

# %%
for init_str, initalizer in initializers:
    for optimizer_str, optimizer in optimizers:
        net = MyNet(layers, initializer=initalizer)
        train_model(net, optimizer_fn=optimizer(), num_epochs=num_epochs, plot_title=f"Initializer: {init_str}, Optimizer: {optimizer_str}")
# Out:
# Initializer: He, Optimizer: Adam
# Epoch 10 : Train Loss 0.201826 , Train acc 0.534000, Valid acc 0.418000
# Epoch 20 : Train Loss 0.178632 , Train acc 0.761000, Valid acc 0.608000
# Epoch 30 : Train Loss 0.166558 , Train acc 0.854000, Valid acc 0.670000
# Epoch 40 : Train Loss 0.160301 , Train acc 0.896000, Valid acc 0.708000
# Epoch 50 : Train Loss 0.156654 , Train acc 0.922000, Valid acc 0.730000
# Epoch 60 : Train Loss 0.154276 , Train acc 0.935000, Valid acc 0.746000
# Epoch 70 : Train Loss 0.152650 , Train acc 0.945000, Valid acc 0.758000
# Epoch 80 : Train Loss 0.151427 , Train acc 0.958000, Valid acc 0.770000
# Epoch 90 : Train Loss 0.150595 , Train acc 0.964000, Valid acc 0.776000
# Epoch 100 : Train Loss 0.150036 , Train acc 0.965000, Valid acc 0.782000
# Epoch 110 : Train Loss 0.149588 , Train acc 0.968000, Valid acc 0.788000
# Epoch 120 : Train Loss 0.149255 , Train acc 0.971000, Valid acc 0.792000
# Epoch 130 : Train Loss 0.149026 , Train acc 0.973000, Valid acc 0.794000
# Epoch 140 : Train Loss 0.148773 , Train acc 0.973000, Valid acc 0.796000
# Epoch 150 : Train Loss 0.148647 , Train acc 0.974000, Valid acc 0.800000
# Epoch 160 : Train Loss 0.148521 , Train acc 0.976000, Valid acc 0.802000
# Epoch 170 : Train Loss 0.148429 , Train acc 0.976000, Valid acc 0.802000
# Epoch 180 : Train Loss 0.148367 , Train acc 0.976000, Valid acc 0.806000
# Epoch 190 : Train Loss 0.148316 , Train acc 0.976000, Valid acc 0.806000
# Epoch 200 : Train Loss 0.148272 , Train acc 0.976000, Valid acc 0.806000
#
# Initializer: He, Optimizer: SGD
# Epoch 10 : Train Loss 0.149129 , Train acc 0.971000, Valid acc 0.798000
# Epoch 20 : Train Loss 0.148025 , Train acc 0.981000, Valid acc 0.820000
# Epoch 30 : Train Loss 0.147844 , Train acc 0.982000, Valid acc 0.820000
# Epoch 40 : Train Loss 0.147815 , Train acc 0.982000, Valid acc 0.820000
# Epoch 50 : Train Loss 0.147775 , Train acc 0.983000, Valid acc 0.824000
# Epoch 60 : Train Loss 0.147704 , Train acc 0.983000, Valid acc 0.824000
# Epoch 70 : Train Loss 0.147698 , Train acc 0.983000, Valid acc 0.822000
# Epoch 80 : Train Loss 0.147628 , Train acc 0.984000, Valid acc 0.820000
# Epoch 90 : Train Loss 0.147496 , Train acc 0.985000, Valid acc 0.818000
# Epoch 100 : Train Loss 0.147489 , Train acc 0.985000, Valid acc 0.820000
# Epoch 110 : Train Loss 0.147483 , Train acc 0.985000, Valid acc 0.820000
# Epoch 120 : Train Loss 0.147475 , Train acc 0.985000, Valid acc 0.818000
# Epoch 130 : Train Loss 0.147432 , Train acc 0.985000, Valid acc 0.822000
# Epoch 140 : Train Loss 0.147240 , Train acc 0.987000, Valid acc 0.820000
# Epoch 150 : Train Loss 0.147193 , Train acc 0.987000, Valid acc 0.824000
# Epoch 160 : Train Loss 0.147187 , Train acc 0.987000, Valid acc 0.824000
# Epoch 170 : Train Loss 0.147182 , Train acc 0.987000, Valid acc 0.824000
# Epoch 180 : Train Loss 0.147087 , Train acc 0.988000, Valid acc 0.822000
# Epoch 190 : Train Loss 0.147085 , Train acc 0.988000, Valid acc 0.822000
# Epoch 200 : Train Loss 0.147083 , Train acc 0.988000, Valid acc 0.822000
#
# Initializer: He, Optimizer: SGD momentum
# Epoch 10 : Train Loss 0.151987 , Train acc 0.954000, Valid acc 0.774000
# Epoch 20 : Train Loss 0.148850 , Train acc 0.971000, Valid acc 0.794000
# Epoch 30 : Train Loss 0.148198 , Train acc 0.977000, Valid acc 0.804000
# Epoch 40 : Train Loss 0.148003 , Train acc 0.978000, Valid acc 0.804000
# Epoch 50 : Train Loss 0.147849 , Train acc 0.980000, Valid acc 0.804000
# Epoch 60 : Train Loss 0.147810 , Train acc 0.980000, Valid acc 0.806000
# Epoch 70 : Train Loss 0.147784 , Train acc 0.980000, Valid acc 0.806000
# Epoch 80 : Train Loss 0.147696 , Train acc 0.981000, Valid acc 0.804000
# Epoch 90 : Train Loss 0.147670 , Train acc 0.981000, Valid acc 0.804000
# Epoch 100 : Train Loss 0.147656 , Train acc 0.981000, Valid acc 0.806000
# Epoch 110 : Train Loss 0.147643 , Train acc 0.981000, Valid acc 0.808000
# Epoch 120 : Train Loss 0.147631 , Train acc 0.981000, Valid acc 0.808000
# Epoch 130 : Train Loss 0.147539 , Train acc 0.982000, Valid acc 0.810000
# Epoch 140 : Train Loss 0.147528 , Train acc 0.982000, Valid acc 0.810000
# Epoch 150 : Train Loss 0.147519 , Train acc 0.982000, Valid acc 0.810000
# Epoch 160 : Train Loss 0.147512 , Train acc 0.982000, Valid acc 0.812000
# Epoch 170 : Train Loss 0.147506 , Train acc 0.983000, Valid acc 0.812000
# Epoch 180 : Train Loss 0.147503 , Train acc 0.983000, Valid acc 0.812000
# Epoch 190 : Train Loss 0.147500 , Train acc 0.983000, Valid acc 0.814000
# Epoch 200 : Train Loss 0.147498 , Train acc 0.983000, Valid acc 0.814000
#
# Initializer: Xavier, Optimizer: Adam
# Epoch 10 : Train Loss 0.199734 , Train acc 0.552000, Valid acc 0.462000
# Epoch 20 : Train Loss 0.171778 , Train acc 0.821000, Valid acc 0.682000
# Epoch 30 : Train Loss 0.160698 , Train acc 0.886000, Valid acc 0.736000
# Epoch 40 : Train Loss 0.156036 , Train acc 0.919000, Valid acc 0.768000
# Epoch 50 : Train Loss 0.153606 , Train acc 0.935000, Valid acc 0.776000
# Epoch 60 : Train Loss 0.152160 , Train acc 0.940000, Valid acc 0.782000
# Epoch 70 : Train Loss 0.151228 , Train acc 0.947000, Valid acc 0.786000
# Epoch 80 : Train Loss 0.150632 , Train acc 0.949000, Valid acc 0.796000
# Epoch 90 : Train Loss 0.150136 , Train acc 0.952000, Valid acc 0.800000
# Epoch 100 : Train Loss 0.149812 , Train acc 0.956000, Valid acc 0.806000
# Epoch 110 : Train Loss 0.149623 , Train acc 0.957000, Valid acc 0.808000
# Epoch 120 : Train Loss 0.149460 , Train acc 0.960000, Valid acc 0.808000
# Epoch 130 : Train Loss 0.149365 , Train acc 0.960000, Valid acc 0.812000
# Epoch 140 : Train Loss 0.149293 , Train acc 0.960000, Valid acc 0.812000
# Epoch 150 : Train Loss 0.149233 , Train acc 0.961000, Valid acc 0.812000
# Epoch 160 : Train Loss 0.149117 , Train acc 0.963000, Valid acc 0.814000
# Epoch 170 : Train Loss 0.149060 , Train acc 0.966000, Valid acc 0.814000
# Epoch 180 : Train Loss 0.148887 , Train acc 0.966000, Valid acc 0.814000
# Epoch 190 : Train Loss 0.148757 , Train acc 0.968000, Valid acc 0.810000
# Epoch 200 : Train Loss 0.148716 , Train acc 0.968000, Valid acc 0.812000
#
# Initializer: Xavier, Optimizer: SGD
# Epoch 10 : Train Loss 0.148675 , Train acc 0.978000, Valid acc 0.814000
# Epoch 20 : Train Loss 0.146954 , Train acc 0.991000, Valid acc 0.824000
# Epoch 30 : Train Loss 0.146697 , Train acc 0.995000, Valid acc 0.826000
# Epoch 40 : Train Loss 0.146517 , Train acc 0.996000, Valid acc 0.826000
# Epoch 50 : Train Loss 0.146511 , Train acc 0.996000, Valid acc 0.828000
# Epoch 60 : Train Loss 0.146507 , Train acc 0.996000, Valid acc 0.830000
# Epoch 70 : Train Loss 0.146504 , Train acc 0.996000, Valid acc 0.826000
# Epoch 80 : Train Loss 0.146501 , Train acc 0.995000, Valid acc 0.826000
# Epoch 90 : Train Loss 0.146495 , Train acc 0.995000, Valid acc 0.826000
# Epoch 100 : Train Loss 0.146489 , Train acc 0.995000, Valid acc 0.826000
# Epoch 110 : Train Loss 0.146489 , Train acc 0.995000, Valid acc 0.826000
# Epoch 120 : Train Loss 0.146488 , Train acc 0.995000, Valid acc 0.826000
# Epoch 130 : Train Loss 0.146487 , Train acc 0.995000, Valid acc 0.828000
# Epoch 140 : Train Loss 0.146486 , Train acc 0.995000, Valid acc 0.828000
# Epoch 150 : Train Loss 0.146486 , Train acc 0.995000, Valid acc 0.828000
# Epoch 160 : Train Loss 0.146485 , Train acc 0.995000, Valid acc 0.828000
# Epoch 170 : Train Loss 0.146484 , Train acc 0.995000, Valid acc 0.828000
# Epoch 180 : Train Loss 0.146415 , Train acc 0.995000, Valid acc 0.826000
# Epoch 190 : Train Loss 0.146390 , Train acc 0.996000, Valid acc 0.828000
# Epoch 200 : Train Loss 0.146389 , Train acc 0.996000, Valid acc 0.828000
#
# Initializer: Xavier, Optimizer: SGD momentum
# Epoch 10 : Train Loss 0.149444 , Train acc 0.974000, Valid acc 0.800000
# Epoch 20 : Train Loss 0.148207 , Train acc 0.983000, Valid acc 0.808000
# Epoch 30 : Train Loss 0.147733 , Train acc 0.984000, Valid acc 0.818000
# Epoch 40 : Train Loss 0.147581 , Train acc 0.986000, Valid acc 0.818000
# Epoch 50 : Train Loss 0.147512 , Train acc 0.987000, Valid acc 0.814000
# Epoch 60 : Train Loss 0.147432 , Train acc 0.987000, Valid acc 0.816000
# Epoch 70 : Train Loss 0.147412 , Train acc 0.987000, Valid acc 0.818000
# Epoch 80 : Train Loss 0.147315 , Train acc 0.988000, Valid acc 0.822000
# Epoch 90 : Train Loss 0.147302 , Train acc 0.988000, Valid acc 0.822000
# Epoch 100 : Train Loss 0.147292 , Train acc 0.988000, Valid acc 0.822000
# Epoch 110 : Train Loss 0.147282 , Train acc 0.988000, Valid acc 0.822000
# Epoch 120 : Train Loss 0.147275 , Train acc 0.988000, Valid acc 0.820000
# Epoch 130 : Train Loss 0.147271 , Train acc 0.988000, Valid acc 0.820000
# Epoch 140 : Train Loss 0.147267 , Train acc 0.988000, Valid acc 0.818000
# Epoch 150 : Train Loss 0.147264 , Train acc 0.988000, Valid acc 0.818000
# Epoch 160 : Train Loss 0.147262 , Train acc 0.988000, Valid acc 0.818000
# Epoch 170 : Train Loss 0.147259 , Train acc 0.988000, Valid acc 0.820000
# Epoch 180 : Train Loss 0.147257 , Train acc 0.988000, Valid acc 0.820000
# Epoch 190 : Train Loss 0.147255 , Train acc 0.988000, Valid acc 0.820000
# Epoch 200 : Train Loss 0.147254 , Train acc 0.988000, Valid acc 0.820000

# %% [markdown]
# # Assignments
#
# Try and add these modifications (might require some Googleing -- an important skill in deep learning):
# - Kaiming He initialization instead of Xavier Glorot
# - add an extra layer
# - use the relu activation function
# - add momentum to the optimizer
# - use the ADAM optimizer instead of stochastic gradient descent
#
# ### Advanced - Regularization
#
# Regularization is VERY important in practice and is used practically every time.
# Many important results are completely dependent on clever use of regularization, and it is something you need to become familiar with if you want to work with deep learning.
#
# - add L1 or L2 weight regularization (aka. weight decay)
# - add dropout to the network (**note** the `net.train()` and `net.eval()` are already in the code)
# - add batchnorm
#
# __Pointers on regularization hyperparameter:__
# 1. L2 and [L1 regularization](http://pytorch.org/docs/master/nn.html#torch.nn.L1Loss) (weight decay of optimization functions)
#   - Normal ranges: 1e-4  -  1e-8
# 1. [Dropout](http://pytorch.org/docs/master/nn.html?highlight=dropout#torch.nn.Dropout). Dropout rate 0.1-0.5
#   - Remember to pick the correct version according to the input dimensionality
#   - **NOTE** call `net.train()` before training to activate random dropout, and call `net.eval()` to deactivate dropout while validating or running inference with model.
# 1. [Batchnorm](http://pytorch.org/docs/master/nn.html#torch.nn.BatchNorm1d): Batchnorm also acts as a regularizer - Often very useful (faster and better convergence)
#   - Remember to pick the correct version according to the input dimensionality
#   - **NOTE** call `net.train()` before training to activate, and call `net.eval()` to have a non-stochastic variant while validating or running inference with model.

# %% [markdown]
# Adding regularization

# %%
dropout_vals = (0.0, 0.1, 0.3, 0.5)
norm_vals = (0., 1e-4, 1e-6, 1e-8)
batch_norm_vals = (False, True)

# dropout_vals = (0.3, 0.5)
# norm_vals = (1e-4, 1e-8)
# batch_norm_vals = (True,)

mynets = {}

for dropout_val in dropout_vals:
    for lambdak in norm_vals:
        for batch_norm_val in batch_norm_vals:
            mynets[dropout_val, lambdak, batch_norm_val] = MyNet(layers, initializer=init.xavier_normal_,
                                                                 lambda1=lambdak, lambda2=lambdak,
                                                                 batch_norm=batch_norm_val, dropout=dropout_val)

# %%
num_epochs = 200

matplotlib.rcParams['figure.max_open_warning'] = 0

for dropout_val, lambdak, batch_norm_val in mynets:
    net = mynets[dropout_val, lambdak, batch_norm_val]
    train_model(net, optimizerAdam(lr=1e-4, weight_decay=lambdak), num_epochs=num_epochs, plot_title=f"dropout={dropout_val},   $\lambda$={lambdak},   batch_norm={batch_norm_val}")
# Out:
# dropout=0.0,   $\lambda$=0.0,   batch_norm=False
# Epoch 10 : Train Loss 0.149932 , Train acc 0.966000, Valid acc 0.792000
# Epoch 20 : Train Loss 0.148040 , Train acc 0.976000, Valid acc 0.806000
# Epoch 30 : Train Loss 0.147810 , Train acc 0.979000, Valid acc 0.814000
# Epoch 40 : Train Loss 0.147750 , Train acc 0.980000, Valid acc 0.810000
# Epoch 50 : Train Loss 0.147717 , Train acc 0.980000, Valid acc 0.812000
# Epoch 60 : Train Loss 0.147691 , Train acc 0.980000, Valid acc 0.810000
# Epoch 70 : Train Loss 0.147675 , Train acc 0.980000, Valid acc 0.812000
# Epoch 80 : Train Loss 0.147667 , Train acc 0.980000, Valid acc 0.812000
# Epoch 90 : Train Loss 0.147661 , Train acc 0.980000, Valid acc 0.810000
# Epoch 100 : Train Loss 0.147656 , Train acc 0.981000, Valid acc 0.812000
# Epoch 110 : Train Loss 0.147318 , Train acc 0.985000, Valid acc 0.812000
# Epoch 120 : Train Loss 0.147314 , Train acc 0.985000, Valid acc 0.812000
# Epoch 130 : Train Loss 0.147311 , Train acc 0.985000, Valid acc 0.812000
# Epoch 140 : Train Loss 0.147309 , Train acc 0.985000, Valid acc 0.812000
# Epoch 150 : Train Loss 0.147307 , Train acc 0.985000, Valid acc 0.816000
# Epoch 160 : Train Loss 0.147305 , Train acc 0.985000, Valid acc 0.816000
# Epoch 170 : Train Loss 0.147304 , Train acc 0.985000, Valid acc 0.820000
# Epoch 180 : Train Loss 0.147303 , Train acc 0.985000, Valid acc 0.818000
# Epoch 190 : Train Loss 0.147302 , Train acc 0.985000, Valid acc 0.822000
# Epoch 200 : Train Loss 0.147217 , Train acc 0.986000, Valid acc 0.812000
#
# dropout=0.0,   $\lambda$=0.0,   batch_norm=True
# Epoch 10 : Train Loss 0.149797 , Train acc 0.972000, Valid acc 0.774000
# Epoch 20 : Train Loss 0.147806 , Train acc 0.984000, Valid acc 0.800000
# Epoch 30 : Train Loss 0.147473 , Train acc 0.987000, Valid acc 0.806000
# Epoch 40 : Train Loss 0.147408 , Train acc 0.987000, Valid acc 0.804000
# Epoch 50 : Train Loss 0.147376 , Train acc 0.987000, Valid acc 0.806000
# Epoch 60 : Train Loss 0.147268 , Train acc 0.987000, Valid acc 0.808000
# Epoch 70 : Train Loss 0.147255 , Train acc 0.987000, Valid acc 0.808000
# Epoch 80 : Train Loss 0.147205 , Train acc 0.988000, Valid acc 0.820000
# Epoch 90 : Train Loss 0.147156 , Train acc 0.989000, Valid acc 0.820000
# Epoch 100 : Train Loss 0.147151 , Train acc 0.989000, Valid acc 0.820000
# Epoch 110 : Train Loss 0.147147 , Train acc 0.988000, Valid acc 0.824000
# Epoch 120 : Train Loss 0.146987 , Train acc 0.991000, Valid acc 0.824000
# Epoch 130 : Train Loss 0.146975 , Train acc 0.991000, Valid acc 0.824000
# Epoch 140 : Train Loss 0.146972 , Train acc 0.991000, Valid acc 0.824000
# Epoch 150 : Train Loss 0.146970 , Train acc 0.991000, Valid acc 0.824000
# Epoch 160 : Train Loss 0.146969 , Train acc 0.991000, Valid acc 0.822000
# Epoch 170 : Train Loss 0.146968 , Train acc 0.991000, Valid acc 0.824000
# Epoch 180 : Train Loss 0.146966 , Train acc 0.991000, Valid acc 0.820000
# Epoch 190 : Train Loss 0.146966 , Train acc 0.991000, Valid acc 0.820000
# Epoch 200 : Train Loss 0.146965 , Train acc 0.991000, Valid acc 0.820000
#
# dropout=0.0,   $\lambda$=0.0001,   batch_norm=False
# Epoch 10 : Train Loss 0.149450 , Train acc 0.976000, Valid acc 0.800000
# Epoch 20 : Train Loss 0.147344 , Train acc 0.989000, Valid acc 0.796000
# Epoch 30 : Train Loss 0.146993 , Train acc 0.991000, Valid acc 0.806000
# Epoch 40 : Train Loss 0.146917 , Train acc 0.991000, Valid acc 0.806000
# Epoch 50 : Train Loss 0.146879 , Train acc 0.991000, Valid acc 0.814000
# Epoch 60 : Train Loss 0.146854 , Train acc 0.991000, Valid acc 0.822000
# Epoch 70 : Train Loss 0.146839 , Train acc 0.992000, Valid acc 0.826000
# Epoch 80 : Train Loss 0.146747 , Train acc 0.992000, Valid acc 0.830000
# Epoch 90 : Train Loss 0.146740 , Train acc 0.992000, Valid acc 0.828000
# Epoch 100 : Train Loss 0.146736 , Train acc 0.993000, Valid acc 0.828000
# Epoch 110 : Train Loss 0.146732 , Train acc 0.993000, Valid acc 0.828000
# Epoch 120 : Train Loss 0.146729 , Train acc 0.993000, Valid acc 0.828000
# Epoch 130 : Train Loss 0.146727 , Train acc 0.993000, Valid acc 0.832000
# Epoch 140 : Train Loss 0.146725 , Train acc 0.993000, Valid acc 0.834000
# Epoch 150 : Train Loss 0.146724 , Train acc 0.993000, Valid acc 0.836000
# Epoch 160 : Train Loss 0.146723 , Train acc 0.993000, Valid acc 0.836000
# Epoch 170 : Train Loss 0.146721 , Train acc 0.993000, Valid acc 0.834000
# Epoch 180 : Train Loss 0.146637 , Train acc 0.994000, Valid acc 0.836000
# Epoch 190 : Train Loss 0.146636 , Train acc 0.994000, Valid acc 0.834000
# Epoch 200 : Train Loss 0.146635 , Train acc 0.994000, Valid acc 0.836000
#
# dropout=0.0,   $\lambda$=0.0001,   batch_norm=True
# Epoch 10 : Train Loss 0.150190 , Train acc 0.971000, Valid acc 0.802000
# Epoch 20 : Train Loss 0.147691 , Train acc 0.986000, Valid acc 0.810000
# Epoch 30 : Train Loss 0.147498 , Train acc 0.986000, Valid acc 0.818000
# Epoch 40 : Train Loss 0.147324 , Train acc 0.988000, Valid acc 0.822000
# Epoch 50 : Train Loss 0.147221 , Train acc 0.988000, Valid acc 0.828000
# Epoch 60 : Train Loss 0.147203 , Train acc 0.988000, Valid acc 0.834000
# Epoch 70 : Train Loss 0.147191 , Train acc 0.988000, Valid acc 0.836000
# Epoch 80 : Train Loss 0.147183 , Train acc 0.988000, Valid acc 0.838000
# Epoch 90 : Train Loss 0.147177 , Train acc 0.988000, Valid acc 0.840000
# Epoch 100 : Train Loss 0.147172 , Train acc 0.988000, Valid acc 0.840000
# Epoch 110 : Train Loss 0.147085 , Train acc 0.988000, Valid acc 0.844000
# Epoch 120 : Train Loss 0.147082 , Train acc 0.988000, Valid acc 0.842000
# Epoch 130 : Train Loss 0.147080 , Train acc 0.988000, Valid acc 0.840000
# Epoch 140 : Train Loss 0.147078 , Train acc 0.988000, Valid acc 0.842000
# Epoch 150 : Train Loss 0.147076 , Train acc 0.988000, Valid acc 0.842000
# Epoch 160 : Train Loss 0.147075 , Train acc 0.988000, Valid acc 0.842000
# Epoch 170 : Train Loss 0.147074 , Train acc 0.988000, Valid acc 0.842000
# Epoch 180 : Train Loss 0.147073 , Train acc 0.988000, Valid acc 0.842000
# Epoch 190 : Train Loss 0.147072 , Train acc 0.988000, Valid acc 0.844000
# Epoch 200 : Train Loss 0.147072 , Train acc 0.988000, Valid acc 0.846000
#
# dropout=0.0,   $\lambda$=1e-06,   batch_norm=False
# Epoch 10 : Train Loss 0.150719 , Train acc 0.964000, Valid acc 0.792000
# Epoch 20 : Train Loss 0.148194 , Train acc 0.980000, Valid acc 0.804000
# Epoch 30 : Train Loss 0.147552 , Train acc 0.985000, Valid acc 0.806000
# Epoch 40 : Train Loss 0.147228 , Train acc 0.987000, Valid acc 0.810000
# Epoch 50 : Train Loss 0.147197 , Train acc 0.987000, Valid acc 0.810000
# Epoch 60 : Train Loss 0.147180 , Train acc 0.987000, Valid acc 0.812000
# Epoch 70 : Train Loss 0.147168 , Train acc 0.987000, Valid acc 0.814000
# Epoch 80 : Train Loss 0.147160 , Train acc 0.987000, Valid acc 0.818000
# Epoch 90 : Train Loss 0.147154 , Train acc 0.988000, Valid acc 0.820000
# Epoch 100 : Train Loss 0.147150 , Train acc 0.988000, Valid acc 0.820000
# Epoch 110 : Train Loss 0.147146 , Train acc 0.988000, Valid acc 0.818000
# Epoch 120 : Train Loss 0.147144 , Train acc 0.988000, Valid acc 0.818000
# Epoch 130 : Train Loss 0.147141 , Train acc 0.988000, Valid acc 0.818000
# Epoch 140 : Train Loss 0.147139 , Train acc 0.988000, Valid acc 0.820000
# Epoch 150 : Train Loss 0.147138 , Train acc 0.988000, Valid acc 0.820000
# Epoch 160 : Train Loss 0.147136 , Train acc 0.988000, Valid acc 0.822000
# Epoch 170 : Train Loss 0.147135 , Train acc 0.988000, Valid acc 0.824000
# Epoch 180 : Train Loss 0.147134 , Train acc 0.988000, Valid acc 0.824000
# Epoch 190 : Train Loss 0.147133 , Train acc 0.988000, Valid acc 0.824000
# Epoch 200 : Train Loss 0.147133 , Train acc 0.988000, Valid acc 0.824000
#
# dropout=0.0,   $\lambda$=1e-06,   batch_norm=True
# Epoch 10 : Train Loss 0.149619 , Train acc 0.976000, Valid acc 0.794000
# Epoch 20 : Train Loss 0.147745 , Train acc 0.985000, Valid acc 0.804000
# Epoch 30 : Train Loss 0.147494 , Train acc 0.988000, Valid acc 0.806000
# Epoch 40 : Train Loss 0.147423 , Train acc 0.987000, Valid acc 0.806000
# Epoch 50 : Train Loss 0.147355 , Train acc 0.988000, Valid acc 0.814000
# Epoch 60 : Train Loss 0.147187 , Train acc 0.991000, Valid acc 0.814000
# Epoch 70 : Train Loss 0.147090 , Train acc 0.990000, Valid acc 0.820000
# Epoch 80 : Train Loss 0.147080 , Train acc 0.990000, Valid acc 0.822000
# Epoch 90 : Train Loss 0.147074 , Train acc 0.990000, Valid acc 0.824000
# Epoch 100 : Train Loss 0.147069 , Train acc 0.990000, Valid acc 0.824000
# Epoch 110 : Train Loss 0.147065 , Train acc 0.990000, Valid acc 0.826000
# Epoch 120 : Train Loss 0.147061 , Train acc 0.991000, Valid acc 0.828000
# Epoch 130 : Train Loss 0.147059 , Train acc 0.991000, Valid acc 0.830000
# Epoch 140 : Train Loss 0.147057 , Train acc 0.991000, Valid acc 0.832000
# Epoch 150 : Train Loss 0.147055 , Train acc 0.991000, Valid acc 0.836000
# Epoch 160 : Train Loss 0.147054 , Train acc 0.991000, Valid acc 0.838000
# Epoch 170 : Train Loss 0.147052 , Train acc 0.991000, Valid acc 0.840000
# Epoch 180 : Train Loss 0.147051 , Train acc 0.990000, Valid acc 0.840000
# Epoch 190 : Train Loss 0.147050 , Train acc 0.990000, Valid acc 0.838000
# Epoch 200 : Train Loss 0.147049 , Train acc 0.990000, Valid acc 0.844000
#
# dropout=0.0,   $\lambda$=1e-08,   batch_norm=False
# Epoch 10 : Train Loss 0.149787 , Train acc 0.970000, Valid acc 0.806000
# Epoch 20 : Train Loss 0.147701 , Train acc 0.981000, Valid acc 0.808000
# Epoch 30 : Train Loss 0.147546 , Train acc 0.981000, Valid acc 0.812000
# Epoch 40 : Train Loss 0.147428 , Train acc 0.982000, Valid acc 0.810000
# Epoch 50 : Train Loss 0.147368 , Train acc 0.982000, Valid acc 0.814000
# Epoch 60 : Train Loss 0.147350 , Train acc 0.982000, Valid acc 0.816000
# Epoch 70 : Train Loss 0.147338 , Train acc 0.983000, Valid acc 0.816000
# Epoch 80 : Train Loss 0.147330 , Train acc 0.983000, Valid acc 0.818000
# Epoch 90 : Train Loss 0.147324 , Train acc 0.983000, Valid acc 0.818000
# Epoch 100 : Train Loss 0.147319 , Train acc 0.983000, Valid acc 0.818000
# Epoch 110 : Train Loss 0.147316 , Train acc 0.983000, Valid acc 0.818000
# Epoch 120 : Train Loss 0.147145 , Train acc 0.985000, Valid acc 0.822000
# Epoch 130 : Train Loss 0.147142 , Train acc 0.985000, Valid acc 0.822000
# Epoch 140 : Train Loss 0.147140 , Train acc 0.985000, Valid acc 0.826000
# Epoch 150 : Train Loss 0.147138 , Train acc 0.986000, Valid acc 0.826000
# Epoch 160 : Train Loss 0.147137 , Train acc 0.986000, Valid acc 0.826000
# Epoch 170 : Train Loss 0.147136 , Train acc 0.986000, Valid acc 0.824000
# Epoch 180 : Train Loss 0.147135 , Train acc 0.987000, Valid acc 0.824000
# Epoch 190 : Train Loss 0.147134 , Train acc 0.987000, Valid acc 0.826000
# Epoch 200 : Train Loss 0.147133 , Train acc 0.987000, Valid acc 0.828000
#
# dropout=0.0,   $\lambda$=1e-08,   batch_norm=True
# Epoch 10 : Train Loss 0.148615 , Train acc 0.982000, Valid acc 0.800000
# Epoch 20 : Train Loss 0.147534 , Train acc 0.986000, Valid acc 0.800000
# Epoch 30 : Train Loss 0.147400 , Train acc 0.987000, Valid acc 0.806000
# Epoch 40 : Train Loss 0.147321 , Train acc 0.988000, Valid acc 0.804000
# Epoch 50 : Train Loss 0.147214 , Train acc 0.988000, Valid acc 0.810000
# Epoch 60 : Train Loss 0.147193 , Train acc 0.988000, Valid acc 0.810000
# Epoch 70 : Train Loss 0.147170 , Train acc 0.988000, Valid acc 0.810000
# Epoch 80 : Train Loss 0.147161 , Train acc 0.988000, Valid acc 0.812000
# Epoch 90 : Train Loss 0.147155 , Train acc 0.988000, Valid acc 0.812000
# Epoch 100 : Train Loss 0.147151 , Train acc 0.988000, Valid acc 0.812000
# Epoch 110 : Train Loss 0.147147 , Train acc 0.988000, Valid acc 0.808000
# Epoch 120 : Train Loss 0.147061 , Train acc 0.989000, Valid acc 0.804000
# Epoch 130 : Train Loss 0.147058 , Train acc 0.989000, Valid acc 0.804000
# Epoch 140 : Train Loss 0.147056 , Train acc 0.989000, Valid acc 0.806000
# Epoch 150 : Train Loss 0.147054 , Train acc 0.989000, Valid acc 0.806000
# Epoch 160 : Train Loss 0.147053 , Train acc 0.989000, Valid acc 0.808000
# Epoch 170 : Train Loss 0.147051 , Train acc 0.989000, Valid acc 0.808000
# Epoch 180 : Train Loss 0.147050 , Train acc 0.989000, Valid acc 0.810000
# Epoch 190 : Train Loss 0.147050 , Train acc 0.989000, Valid acc 0.814000
# Epoch 200 : Train Loss 0.147049 , Train acc 0.989000, Valid acc 0.810000
#
# dropout=0.1,   $\lambda$=0.0,   batch_norm=False
# Epoch 10 : Train Loss 0.156291 , Train acc 0.945000, Valid acc 0.794000
# Epoch 20 : Train Loss 0.149298 , Train acc 0.982000, Valid acc 0.814000
# Epoch 30 : Train Loss 0.147665 , Train acc 0.992000, Valid acc 0.822000
# Epoch 40 : Train Loss 0.147130 , Train acc 0.995000, Valid acc 0.826000
# Epoch 50 : Train Loss 0.146946 , Train acc 0.995000, Valid acc 0.824000
# Epoch 60 : Train Loss 0.146804 , Train acc 0.995000, Valid acc 0.826000
# Epoch 70 : Train Loss 0.146652 , Train acc 0.996000, Valid acc 0.826000
# Epoch 80 : Train Loss 0.146543 , Train acc 0.997000, Valid acc 0.828000
# Epoch 90 : Train Loss 0.146513 , Train acc 0.997000, Valid acc 0.832000
# Epoch 100 : Train Loss 0.146471 , Train acc 0.998000, Valid acc 0.830000
# Epoch 110 : Train Loss 0.146376 , Train acc 0.998000, Valid acc 0.834000
# Epoch 120 : Train Loss 0.146369 , Train acc 0.998000, Valid acc 0.832000
# Epoch 130 : Train Loss 0.146346 , Train acc 0.998000, Valid acc 0.830000
# Epoch 140 : Train Loss 0.146357 , Train acc 0.998000, Valid acc 0.832000
# Epoch 150 : Train Loss 0.146345 , Train acc 0.998000, Valid acc 0.832000
# Epoch 160 : Train Loss 0.146259 , Train acc 0.999000, Valid acc 0.832000
# Epoch 170 : Train Loss 0.146247 , Train acc 0.999000, Valid acc 0.836000
# Epoch 180 : Train Loss 0.146248 , Train acc 0.999000, Valid acc 0.836000
# Epoch 190 : Train Loss 0.146230 , Train acc 0.999000, Valid acc 0.836000
# Epoch 200 : Train Loss 0.146230 , Train acc 0.999000, Valid acc 0.834000
#
# dropout=0.1,   $\lambda$=0.0,   batch_norm=True
# Epoch 10 : Train Loss 0.156963 , Train acc 0.946000, Valid acc 0.808000
# Epoch 20 : Train Loss 0.149154 , Train acc 0.985000, Valid acc 0.828000
# Epoch 30 : Train Loss 0.147931 , Train acc 0.987000, Valid acc 0.830000
# Epoch 40 : Train Loss 0.147586 , Train acc 0.989000, Valid acc 0.842000
# Epoch 50 : Train Loss 0.147239 , Train acc 0.993000, Valid acc 0.842000
# Epoch 60 : Train Loss 0.146821 , Train acc 0.996000, Valid acc 0.840000
# Epoch 70 : Train Loss 0.146656 , Train acc 0.996000, Valid acc 0.844000
# Epoch 80 : Train Loss 0.146566 , Train acc 0.998000, Valid acc 0.844000
# Epoch 90 : Train Loss 0.146422 , Train acc 0.998000, Valid acc 0.842000
# Epoch 100 : Train Loss 0.146401 , Train acc 0.998000, Valid acc 0.842000
# Epoch 110 : Train Loss 0.146382 , Train acc 0.998000, Valid acc 0.844000
# Epoch 120 : Train Loss 0.146369 , Train acc 0.998000, Valid acc 0.844000
# Epoch 130 : Train Loss 0.146345 , Train acc 0.998000, Valid acc 0.848000
# Epoch 140 : Train Loss 0.146342 , Train acc 0.998000, Valid acc 0.848000
# Epoch 150 : Train Loss 0.146355 , Train acc 0.998000, Valid acc 0.848000
# Epoch 160 : Train Loss 0.146328 , Train acc 0.998000, Valid acc 0.848000
# Epoch 170 : Train Loss 0.146245 , Train acc 0.999000, Valid acc 0.850000
# Epoch 180 : Train Loss 0.146228 , Train acc 0.999000, Valid acc 0.850000
# Epoch 190 : Train Loss 0.146227 , Train acc 0.999000, Valid acc 0.848000
# Epoch 200 : Train Loss 0.146228 , Train acc 0.999000, Valid acc 0.852000
#
# dropout=0.1,   $\lambda$=0.0001,   batch_norm=False
# Epoch 10 : Train Loss 0.156243 , Train acc 0.945000, Valid acc 0.808000
# Epoch 20 : Train Loss 0.149255 , Train acc 0.985000, Valid acc 0.828000
# Epoch 30 : Train Loss 0.147841 , Train acc 0.989000, Valid acc 0.832000
# Epoch 40 : Train Loss 0.147320 , Train acc 0.992000, Valid acc 0.838000
# Epoch 50 : Train Loss 0.147020 , Train acc 0.994000, Valid acc 0.834000
# Epoch 60 : Train Loss 0.146742 , Train acc 0.996000, Valid acc 0.836000
# Epoch 70 : Train Loss 0.146693 , Train acc 0.996000, Valid acc 0.842000
# Epoch 80 : Train Loss 0.146651 , Train acc 0.996000, Valid acc 0.850000
# Epoch 90 : Train Loss 0.146614 , Train acc 0.996000, Valid acc 0.850000
# Epoch 100 : Train Loss 0.146500 , Train acc 0.997000, Valid acc 0.850000
# Epoch 110 : Train Loss 0.146402 , Train acc 0.998000, Valid acc 0.852000
# Epoch 120 : Train Loss 0.146383 , Train acc 0.998000, Valid acc 0.852000
# Epoch 130 : Train Loss 0.146380 , Train acc 0.998000, Valid acc 0.854000
# Epoch 140 : Train Loss 0.146371 , Train acc 0.998000, Valid acc 0.852000
# Epoch 150 : Train Loss 0.146363 , Train acc 0.998000, Valid acc 0.854000
# Epoch 160 : Train Loss 0.146344 , Train acc 0.998000, Valid acc 0.854000
# Epoch 170 : Train Loss 0.146269 , Train acc 0.999000, Valid acc 0.856000
# Epoch 180 : Train Loss 0.146239 , Train acc 0.999000, Valid acc 0.856000
# Epoch 190 : Train Loss 0.146244 , Train acc 0.999000, Valid acc 0.860000
# Epoch 200 : Train Loss 0.146241 , Train acc 0.999000, Valid acc 0.856000
#
# dropout=0.1,   $\lambda$=0.0001,   batch_norm=True
# Epoch 10 : Train Loss 0.155682 , Train acc 0.959000, Valid acc 0.824000
# Epoch 20 : Train Loss 0.149167 , Train acc 0.987000, Valid acc 0.834000
# Epoch 30 : Train Loss 0.147916 , Train acc 0.990000, Valid acc 0.838000
# Epoch 40 : Train Loss 0.147628 , Train acc 0.991000, Valid acc 0.834000
# Epoch 50 : Train Loss 0.147160 , Train acc 0.992000, Valid acc 0.834000
# Epoch 60 : Train Loss 0.147070 , Train acc 0.993000, Valid acc 0.838000
# Epoch 70 : Train Loss 0.146960 , Train acc 0.993000, Valid acc 0.842000
# Epoch 80 : Train Loss 0.146797 , Train acc 0.994000, Valid acc 0.854000
# Epoch 90 : Train Loss 0.146589 , Train acc 0.996000, Valid acc 0.852000
# Epoch 100 : Train Loss 0.146578 , Train acc 0.996000, Valid acc 0.852000
# Epoch 110 : Train Loss 0.146563 , Train acc 0.996000, Valid acc 0.854000
# Epoch 120 : Train Loss 0.146533 , Train acc 0.996000, Valid acc 0.852000
# Epoch 130 : Train Loss 0.146570 , Train acc 0.996000, Valid acc 0.854000
# Epoch 140 : Train Loss 0.146566 , Train acc 0.996000, Valid acc 0.854000
# Epoch 150 : Train Loss 0.146518 , Train acc 0.996000, Valid acc 0.846000
# Epoch 160 : Train Loss 0.146529 , Train acc 0.996000, Valid acc 0.858000
# Epoch 170 : Train Loss 0.146505 , Train acc 0.996000, Valid acc 0.858000
# Epoch 180 : Train Loss 0.146496 , Train acc 0.996000, Valid acc 0.854000
# Epoch 190 : Train Loss 0.146411 , Train acc 0.997000, Valid acc 0.860000
# Epoch 200 : Train Loss 0.146399 , Train acc 0.998000, Valid acc 0.858000
#
# dropout=0.1,   $\lambda$=1e-06,   batch_norm=False
# Epoch 10 : Train Loss 0.156016 , Train acc 0.953000, Valid acc 0.806000
# Epoch 20 : Train Loss 0.149408 , Train acc 0.984000, Valid acc 0.830000
# Epoch 30 : Train Loss 0.147894 , Train acc 0.988000, Valid acc 0.840000
# Epoch 40 : Train Loss 0.147457 , Train acc 0.992000, Valid acc 0.838000
# Epoch 50 : Train Loss 0.147000 , Train acc 0.994000, Valid acc 0.842000
# Epoch 60 : Train Loss 0.146929 , Train acc 0.994000, Valid acc 0.840000
# Epoch 70 : Train Loss 0.146798 , Train acc 0.995000, Valid acc 0.838000
# Epoch 80 : Train Loss 0.146715 , Train acc 0.995000, Valid acc 0.840000
# Epoch 90 : Train Loss 0.146589 , Train acc 0.996000, Valid acc 0.844000
# Epoch 100 : Train Loss 0.146598 , Train acc 0.996000, Valid acc 0.846000
# Epoch 110 : Train Loss 0.146552 , Train acc 0.996000, Valid acc 0.848000
# Epoch 120 : Train Loss 0.146539 , Train acc 0.995000, Valid acc 0.852000
# Epoch 130 : Train Loss 0.146349 , Train acc 0.997000, Valid acc 0.848000
# Epoch 140 : Train Loss 0.146339 , Train acc 0.997000, Valid acc 0.848000
# Epoch 150 : Train Loss 0.146254 , Train acc 0.998000, Valid acc 0.852000
# Epoch 160 : Train Loss 0.146253 , Train acc 0.998000, Valid acc 0.850000
# Epoch 170 : Train Loss 0.146237 , Train acc 0.999000, Valid acc 0.846000
# Epoch 180 : Train Loss 0.146233 , Train acc 0.998000, Valid acc 0.846000
# Epoch 190 : Train Loss 0.146234 , Train acc 0.999000, Valid acc 0.848000
# Epoch 200 : Train Loss 0.146228 , Train acc 0.999000, Valid acc 0.852000
#
# dropout=0.1,   $\lambda$=1e-06,   batch_norm=True
# Epoch 10 : Train Loss 0.156048 , Train acc 0.954000, Valid acc 0.818000
# Epoch 20 : Train Loss 0.149165 , Train acc 0.984000, Valid acc 0.842000
# Epoch 30 : Train Loss 0.147866 , Train acc 0.991000, Valid acc 0.844000
# Epoch 40 : Train Loss 0.147321 , Train acc 0.993000, Valid acc 0.854000
# Epoch 50 : Train Loss 0.147051 , Train acc 0.994000, Valid acc 0.856000
# Epoch 60 : Train Loss 0.146896 , Train acc 0.994000, Valid acc 0.852000
# Epoch 70 : Train Loss 0.146769 , Train acc 0.995000, Valid acc 0.856000
# Epoch 80 : Train Loss 0.146548 , Train acc 0.997000, Valid acc 0.854000
# Epoch 90 : Train Loss 0.146485 , Train acc 0.997000, Valid acc 0.856000
# Epoch 100 : Train Loss 0.146474 , Train acc 0.997000, Valid acc 0.854000
# Epoch 110 : Train Loss 0.146477 , Train acc 0.997000, Valid acc 0.856000
# Epoch 120 : Train Loss 0.146486 , Train acc 0.997000, Valid acc 0.858000
# Epoch 130 : Train Loss 0.146341 , Train acc 0.998000, Valid acc 0.860000
# Epoch 140 : Train Loss 0.146344 , Train acc 0.998000, Valid acc 0.864000
# Epoch 150 : Train Loss 0.146352 , Train acc 0.998000, Valid acc 0.862000
# Epoch 160 : Train Loss 0.146342 , Train acc 0.998000, Valid acc 0.860000
# Epoch 170 : Train Loss 0.146330 , Train acc 0.998000, Valid acc 0.860000
# Epoch 180 : Train Loss 0.146319 , Train acc 0.998000, Valid acc 0.862000
# Epoch 190 : Train Loss 0.146318 , Train acc 0.998000, Valid acc 0.866000
# Epoch 200 : Train Loss 0.146230 , Train acc 0.999000, Valid acc 0.864000
#
# dropout=0.1,   $\lambda$=1e-08,   batch_norm=False
# Epoch 10 : Train Loss 0.156687 , Train acc 0.941000, Valid acc 0.790000
# Epoch 20 : Train Loss 0.149308 , Train acc 0.985000, Valid acc 0.816000
# Epoch 30 : Train Loss 0.147933 , Train acc 0.990000, Valid acc 0.832000
# Epoch 40 : Train Loss 0.147232 , Train acc 0.994000, Valid acc 0.834000
# Epoch 50 : Train Loss 0.147030 , Train acc 0.994000, Valid acc 0.830000
# Epoch 60 : Train Loss 0.146900 , Train acc 0.994000, Valid acc 0.836000
# Epoch 70 : Train Loss 0.146728 , Train acc 0.995000, Valid acc 0.834000
# Epoch 80 : Train Loss 0.146753 , Train acc 0.995000, Valid acc 0.834000
# Epoch 90 : Train Loss 0.146665 , Train acc 0.996000, Valid acc 0.838000
# Epoch 100 : Train Loss 0.146574 , Train acc 0.996000, Valid acc 0.836000
# Epoch 110 : Train Loss 0.146465 , Train acc 0.997000, Valid acc 0.834000
# Epoch 120 : Train Loss 0.146442 , Train acc 0.997000, Valid acc 0.842000
# Epoch 130 : Train Loss 0.146422 , Train acc 0.997000, Valid acc 0.846000
# Epoch 140 : Train Loss 0.146429 , Train acc 0.997000, Valid acc 0.846000
# Epoch 150 : Train Loss 0.146480 , Train acc 0.997000, Valid acc 0.842000
# Epoch 160 : Train Loss 0.146410 , Train acc 0.997000, Valid acc 0.840000
# Epoch 170 : Train Loss 0.146415 , Train acc 0.997000, Valid acc 0.838000
# Epoch 180 : Train Loss 0.146405 , Train acc 0.997000, Valid acc 0.842000
# Epoch 190 : Train Loss 0.146396 , Train acc 0.997000, Valid acc 0.842000
# Epoch 200 : Train Loss 0.146315 , Train acc 0.998000, Valid acc 0.842000
#
# dropout=0.1,   $\lambda$=1e-08,   batch_norm=True
# Epoch 10 : Train Loss 0.155915 , Train acc 0.953000, Valid acc 0.794000
# Epoch 20 : Train Loss 0.149237 , Train acc 0.988000, Valid acc 0.820000
# Epoch 30 : Train Loss 0.147518 , Train acc 0.994000, Valid acc 0.834000
# Epoch 40 : Train Loss 0.146984 , Train acc 0.996000, Valid acc 0.834000
# Epoch 50 : Train Loss 0.146790 , Train acc 0.996000, Valid acc 0.838000
# Epoch 60 : Train Loss 0.146667 , Train acc 0.997000, Valid acc 0.830000
# Epoch 70 : Train Loss 0.146511 , Train acc 0.998000, Valid acc 0.838000
# Epoch 80 : Train Loss 0.146418 , Train acc 0.998000, Valid acc 0.834000
# Epoch 90 : Train Loss 0.146401 , Train acc 0.998000, Valid acc 0.836000
# Epoch 100 : Train Loss 0.146333 , Train acc 0.999000, Valid acc 0.836000
# Epoch 110 : Train Loss 0.146276 , Train acc 0.999000, Valid acc 0.846000
# Epoch 120 : Train Loss 0.146272 , Train acc 0.999000, Valid acc 0.842000
# Epoch 130 : Train Loss 0.146304 , Train acc 0.999000, Valid acc 0.842000
# Epoch 140 : Train Loss 0.146246 , Train acc 0.999000, Valid acc 0.848000
# Epoch 150 : Train Loss 0.146240 , Train acc 0.999000, Valid acc 0.842000
# Epoch 160 : Train Loss 0.146243 , Train acc 0.999000, Valid acc 0.844000
# Epoch 170 : Train Loss 0.146236 , Train acc 0.999000, Valid acc 0.842000
# Epoch 180 : Train Loss 0.146230 , Train acc 0.999000, Valid acc 0.844000
# Epoch 190 : Train Loss 0.146268 , Train acc 0.999000, Valid acc 0.846000
# Epoch 200 : Train Loss 0.146228 , Train acc 0.999000, Valid acc 0.844000
#
# dropout=0.3,   $\lambda$=0.0,   batch_norm=False
# Epoch 10 : Train Loss 0.175067 , Train acc 0.836000, Valid acc 0.756000
# Epoch 20 : Train Loss 0.162858 , Train acc 0.920000, Valid acc 0.818000
# Epoch 30 : Train Loss 0.156359 , Train acc 0.956000, Valid acc 0.846000
# Epoch 40 : Train Loss 0.154171 , Train acc 0.970000, Valid acc 0.842000
# Epoch 50 : Train Loss 0.151896 , Train acc 0.977000, Valid acc 0.842000
# Epoch 60 : Train Loss 0.150658 , Train acc 0.981000, Valid acc 0.842000
# Epoch 70 : Train Loss 0.150030 , Train acc 0.983000, Valid acc 0.848000
# Epoch 80 : Train Loss 0.149635 , Train acc 0.988000, Valid acc 0.852000
# Epoch 90 : Train Loss 0.149280 , Train acc 0.990000, Valid acc 0.848000
# Epoch 100 : Train Loss 0.148850 , Train acc 0.990000, Valid acc 0.854000
# Epoch 110 : Train Loss 0.148246 , Train acc 0.991000, Valid acc 0.854000
# Epoch 120 : Train Loss 0.148628 , Train acc 0.991000, Valid acc 0.858000
# Epoch 130 : Train Loss 0.147743 , Train acc 0.992000, Valid acc 0.856000
# Epoch 140 : Train Loss 0.147917 , Train acc 0.992000, Valid acc 0.860000
# Epoch 150 : Train Loss 0.147628 , Train acc 0.992000, Valid acc 0.858000
# Epoch 160 : Train Loss 0.147581 , Train acc 0.993000, Valid acc 0.864000
# Epoch 170 : Train Loss 0.147341 , Train acc 0.994000, Valid acc 0.864000
# Epoch 180 : Train Loss 0.147255 , Train acc 0.994000, Valid acc 0.862000
# Epoch 190 : Train Loss 0.147102 , Train acc 0.994000, Valid acc 0.864000
# Epoch 200 : Train Loss 0.147208 , Train acc 0.994000, Valid acc 0.864000
#
# dropout=0.3,   $\lambda$=0.0,   batch_norm=True
# Epoch 10 : Train Loss 0.175062 , Train acc 0.856000, Valid acc 0.768000
# Epoch 20 : Train Loss 0.162167 , Train acc 0.924000, Valid acc 0.812000
# Epoch 30 : Train Loss 0.156593 , Train acc 0.958000, Valid acc 0.840000
# Epoch 40 : Train Loss 0.154362 , Train acc 0.969000, Valid acc 0.846000
# Epoch 50 : Train Loss 0.152330 , Train acc 0.979000, Valid acc 0.852000
# Epoch 60 : Train Loss 0.150986 , Train acc 0.982000, Valid acc 0.856000
# Epoch 70 : Train Loss 0.149560 , Train acc 0.985000, Valid acc 0.860000
# Epoch 80 : Train Loss 0.149644 , Train acc 0.987000, Valid acc 0.856000
# Epoch 90 : Train Loss 0.148970 , Train acc 0.988000, Valid acc 0.858000
# Epoch 100 : Train Loss 0.148586 , Train acc 0.989000, Valid acc 0.854000
# Epoch 110 : Train Loss 0.148085 , Train acc 0.989000, Valid acc 0.852000
# Epoch 120 : Train Loss 0.148094 , Train acc 0.990000, Valid acc 0.848000
# Epoch 130 : Train Loss 0.147997 , Train acc 0.990000, Valid acc 0.844000
# Epoch 140 : Train Loss 0.147756 , Train acc 0.991000, Valid acc 0.848000
# Epoch 150 : Train Loss 0.147623 , Train acc 0.991000, Valid acc 0.842000
# Epoch 160 : Train Loss 0.147704 , Train acc 0.992000, Valid acc 0.856000
# Epoch 170 : Train Loss 0.147357 , Train acc 0.992000, Valid acc 0.856000
# Epoch 180 : Train Loss 0.147335 , Train acc 0.992000, Valid acc 0.852000
# Epoch 190 : Train Loss 0.147403 , Train acc 0.992000, Valid acc 0.858000
# Epoch 200 : Train Loss 0.147269 , Train acc 0.993000, Valid acc 0.854000
#
# dropout=0.3,   $\lambda$=0.0001,   batch_norm=False
# Epoch 10 : Train Loss 0.176000 , Train acc 0.824000, Valid acc 0.732000
# Epoch 20 : Train Loss 0.163553 , Train acc 0.907000, Valid acc 0.798000
# Epoch 30 : Train Loss 0.157872 , Train acc 0.949000, Valid acc 0.822000
# Epoch 40 : Train Loss 0.154242 , Train acc 0.968000, Valid acc 0.834000
# Epoch 50 : Train Loss 0.152845 , Train acc 0.978000, Valid acc 0.846000
# Epoch 60 : Train Loss 0.150942 , Train acc 0.983000, Valid acc 0.858000
# Epoch 70 : Train Loss 0.150047 , Train acc 0.987000, Valid acc 0.860000
# Epoch 80 : Train Loss 0.149629 , Train acc 0.987000, Valid acc 0.860000
# Epoch 90 : Train Loss 0.149007 , Train acc 0.988000, Valid acc 0.864000
# Epoch 100 : Train Loss 0.148546 , Train acc 0.988000, Valid acc 0.862000
# Epoch 110 : Train Loss 0.148757 , Train acc 0.989000, Valid acc 0.866000
# Epoch 120 : Train Loss 0.148176 , Train acc 0.989000, Valid acc 0.868000
# Epoch 130 : Train Loss 0.147732 , Train acc 0.989000, Valid acc 0.868000
# Epoch 140 : Train Loss 0.148022 , Train acc 0.991000, Valid acc 0.870000
# Epoch 150 : Train Loss 0.147976 , Train acc 0.992000, Valid acc 0.870000
# Epoch 160 : Train Loss 0.147506 , Train acc 0.992000, Valid acc 0.866000
# Epoch 170 : Train Loss 0.147304 , Train acc 0.992000, Valid acc 0.872000
# Epoch 180 : Train Loss 0.147372 , Train acc 0.993000, Valid acc 0.872000
# Epoch 190 : Train Loss 0.147206 , Train acc 0.993000, Valid acc 0.866000
# Epoch 200 : Train Loss 0.147475 , Train acc 0.993000, Valid acc 0.868000
#
# dropout=0.3,   $\lambda$=0.0001,   batch_norm=True
# Epoch 10 : Train Loss 0.174577 , Train acc 0.857000, Valid acc 0.750000
# Epoch 20 : Train Loss 0.161486 , Train acc 0.917000, Valid acc 0.812000
# Epoch 30 : Train Loss 0.156587 , Train acc 0.946000, Valid acc 0.848000
# Epoch 40 : Train Loss 0.153838 , Train acc 0.965000, Valid acc 0.848000
# Epoch 50 : Train Loss 0.152776 , Train acc 0.980000, Valid acc 0.842000
# Epoch 60 : Train Loss 0.150546 , Train acc 0.982000, Valid acc 0.848000
# Epoch 70 : Train Loss 0.149828 , Train acc 0.984000, Valid acc 0.844000
# Epoch 80 : Train Loss 0.149482 , Train acc 0.988000, Valid acc 0.850000
# Epoch 90 : Train Loss 0.149232 , Train acc 0.990000, Valid acc 0.852000
# Epoch 100 : Train Loss 0.148689 , Train acc 0.990000, Valid acc 0.848000
# Epoch 110 : Train Loss 0.147997 , Train acc 0.990000, Valid acc 0.850000
# Epoch 120 : Train Loss 0.148109 , Train acc 0.990000, Valid acc 0.856000
# Epoch 130 : Train Loss 0.147845 , Train acc 0.991000, Valid acc 0.860000
# Epoch 140 : Train Loss 0.147601 , Train acc 0.991000, Valid acc 0.868000
# Epoch 150 : Train Loss 0.147489 , Train acc 0.993000, Valid acc 0.864000
# Epoch 160 : Train Loss 0.147392 , Train acc 0.993000, Valid acc 0.864000
# Epoch 170 : Train Loss 0.147473 , Train acc 0.993000, Valid acc 0.868000
# Epoch 180 : Train Loss 0.147253 , Train acc 0.993000, Valid acc 0.872000
# Epoch 190 : Train Loss 0.147134 , Train acc 0.993000, Valid acc 0.868000
# Epoch 200 : Train Loss 0.147426 , Train acc 0.993000, Valid acc 0.870000
#
# dropout=0.3,   $\lambda$=1e-06,   batch_norm=False
# Epoch 10 : Train Loss 0.175236 , Train acc 0.823000, Valid acc 0.746000
# Epoch 20 : Train Loss 0.163104 , Train acc 0.912000, Valid acc 0.800000
# Epoch 30 : Train Loss 0.156828 , Train acc 0.951000, Valid acc 0.832000
# Epoch 40 : Train Loss 0.154016 , Train acc 0.970000, Valid acc 0.844000
# Epoch 50 : Train Loss 0.151973 , Train acc 0.977000, Valid acc 0.842000
# Epoch 60 : Train Loss 0.151105 , Train acc 0.981000, Valid acc 0.848000
# Epoch 70 : Train Loss 0.149915 , Train acc 0.984000, Valid acc 0.844000
# Epoch 80 : Train Loss 0.149246 , Train acc 0.985000, Valid acc 0.846000
# Epoch 90 : Train Loss 0.148890 , Train acc 0.987000, Valid acc 0.840000
# Epoch 100 : Train Loss 0.148854 , Train acc 0.989000, Valid acc 0.848000
# Epoch 110 : Train Loss 0.148434 , Train acc 0.990000, Valid acc 0.852000
# Epoch 120 : Train Loss 0.148242 , Train acc 0.991000, Valid acc 0.858000
# Epoch 130 : Train Loss 0.147883 , Train acc 0.991000, Valid acc 0.854000
# Epoch 140 : Train Loss 0.147796 , Train acc 0.991000, Valid acc 0.856000
# Epoch 150 : Train Loss 0.147524 , Train acc 0.992000, Valid acc 0.856000
# Epoch 160 : Train Loss 0.147597 , Train acc 0.992000, Valid acc 0.850000
# Epoch 170 : Train Loss 0.147463 , Train acc 0.992000, Valid acc 0.854000
# Epoch 180 : Train Loss 0.147372 , Train acc 0.993000, Valid acc 0.850000
# Epoch 190 : Train Loss 0.147189 , Train acc 0.993000, Valid acc 0.858000
# Epoch 200 : Train Loss 0.147172 , Train acc 0.993000, Valid acc 0.858000
#
# dropout=0.3,   $\lambda$=1e-06,   batch_norm=True
# Epoch 10 : Train Loss 0.175494 , Train acc 0.840000, Valid acc 0.746000
# Epoch 20 : Train Loss 0.162188 , Train acc 0.927000, Valid acc 0.796000
# Epoch 30 : Train Loss 0.157430 , Train acc 0.949000, Valid acc 0.814000
# Epoch 40 : Train Loss 0.153825 , Train acc 0.970000, Valid acc 0.828000
# Epoch 50 : Train Loss 0.152439 , Train acc 0.977000, Valid acc 0.838000
# Epoch 60 : Train Loss 0.150876 , Train acc 0.987000, Valid acc 0.846000
# Epoch 70 : Train Loss 0.150665 , Train acc 0.987000, Valid acc 0.840000
# Epoch 80 : Train Loss 0.148940 , Train acc 0.989000, Valid acc 0.846000
# Epoch 90 : Train Loss 0.148913 , Train acc 0.989000, Valid acc 0.842000
# Epoch 100 : Train Loss 0.148382 , Train acc 0.989000, Valid acc 0.850000
# Epoch 110 : Train Loss 0.148145 , Train acc 0.989000, Valid acc 0.850000
# Epoch 120 : Train Loss 0.148015 , Train acc 0.990000, Valid acc 0.852000
# Epoch 130 : Train Loss 0.147958 , Train acc 0.991000, Valid acc 0.848000
# Epoch 140 : Train Loss 0.147836 , Train acc 0.992000, Valid acc 0.846000
# Epoch 150 : Train Loss 0.147709 , Train acc 0.992000, Valid acc 0.848000
# Epoch 160 : Train Loss 0.147458 , Train acc 0.992000, Valid acc 0.852000
# Epoch 170 : Train Loss 0.147610 , Train acc 0.992000, Valid acc 0.852000
# Epoch 180 : Train Loss 0.147396 , Train acc 0.992000, Valid acc 0.850000
# Epoch 190 : Train Loss 0.147385 , Train acc 0.993000, Valid acc 0.852000
# Epoch 200 : Train Loss 0.147124 , Train acc 0.993000, Valid acc 0.854000
#
# dropout=0.3,   $\lambda$=1e-08,   batch_norm=False
# Epoch 10 : Train Loss 0.174053 , Train acc 0.845000, Valid acc 0.752000
# Epoch 20 : Train Loss 0.161744 , Train acc 0.925000, Valid acc 0.820000
# Epoch 30 : Train Loss 0.157196 , Train acc 0.956000, Valid acc 0.844000
# Epoch 40 : Train Loss 0.154062 , Train acc 0.970000, Valid acc 0.852000
# Epoch 50 : Train Loss 0.152269 , Train acc 0.974000, Valid acc 0.856000
# Epoch 60 : Train Loss 0.151238 , Train acc 0.978000, Valid acc 0.858000
# Epoch 70 : Train Loss 0.150259 , Train acc 0.982000, Valid acc 0.858000
# Epoch 80 : Train Loss 0.148809 , Train acc 0.984000, Valid acc 0.860000
# Epoch 90 : Train Loss 0.148983 , Train acc 0.988000, Valid acc 0.864000
# Epoch 100 : Train Loss 0.148442 , Train acc 0.989000, Valid acc 0.852000
# Epoch 110 : Train Loss 0.148317 , Train acc 0.989000, Valid acc 0.854000
# Epoch 120 : Train Loss 0.148012 , Train acc 0.990000, Valid acc 0.852000
# Epoch 130 : Train Loss 0.148056 , Train acc 0.990000, Valid acc 0.854000
# Epoch 140 : Train Loss 0.147876 , Train acc 0.990000, Valid acc 0.858000
# Epoch 150 : Train Loss 0.147595 , Train acc 0.992000, Valid acc 0.860000
# Epoch 160 : Train Loss 0.147494 , Train acc 0.992000, Valid acc 0.860000
# Epoch 170 : Train Loss 0.147489 , Train acc 0.993000, Valid acc 0.862000
# Epoch 180 : Train Loss 0.147317 , Train acc 0.993000, Valid acc 0.864000
# Epoch 190 : Train Loss 0.147413 , Train acc 0.993000, Valid acc 0.862000
# Epoch 200 : Train Loss 0.147461 , Train acc 0.993000, Valid acc 0.862000
#
# dropout=0.3,   $\lambda$=1e-08,   batch_norm=True
# Epoch 10 : Train Loss 0.176304 , Train acc 0.830000, Valid acc 0.746000
# Epoch 20 : Train Loss 0.162685 , Train acc 0.913000, Valid acc 0.808000
# Epoch 30 : Train Loss 0.157977 , Train acc 0.950000, Valid acc 0.842000
# Epoch 40 : Train Loss 0.154127 , Train acc 0.970000, Valid acc 0.848000
# Epoch 50 : Train Loss 0.152635 , Train acc 0.977000, Valid acc 0.856000
# Epoch 60 : Train Loss 0.151109 , Train acc 0.981000, Valid acc 0.852000
# Epoch 70 : Train Loss 0.150296 , Train acc 0.984000, Valid acc 0.860000
# Epoch 80 : Train Loss 0.149212 , Train acc 0.988000, Valid acc 0.866000
# Epoch 90 : Train Loss 0.148599 , Train acc 0.989000, Valid acc 0.860000
# Epoch 100 : Train Loss 0.148900 , Train acc 0.990000, Valid acc 0.866000
# Epoch 110 : Train Loss 0.148114 , Train acc 0.991000, Valid acc 0.858000
# Epoch 120 : Train Loss 0.148080 , Train acc 0.992000, Valid acc 0.860000
# Epoch 130 : Train Loss 0.147541 , Train acc 0.993000, Valid acc 0.864000
# Epoch 140 : Train Loss 0.147530 , Train acc 0.993000, Valid acc 0.872000
# Epoch 150 : Train Loss 0.147596 , Train acc 0.994000, Valid acc 0.868000
# Epoch 160 : Train Loss 0.147427 , Train acc 0.994000, Valid acc 0.882000
# Epoch 170 : Train Loss 0.147395 , Train acc 0.994000, Valid acc 0.864000
# Epoch 180 : Train Loss 0.147257 , Train acc 0.994000, Valid acc 0.870000
# Epoch 190 : Train Loss 0.147161 , Train acc 0.995000, Valid acc 0.868000
# Epoch 200 : Train Loss 0.147060 , Train acc 0.995000, Valid acc 0.874000
#
# dropout=0.5,   $\lambda$=0.0,   batch_norm=False
# Epoch 10 : Train Loss 0.208637 , Train acc 0.607000, Valid acc 0.522000
# Epoch 20 : Train Loss 0.187327 , Train acc 0.733000, Valid acc 0.660000
# Epoch 30 : Train Loss 0.176976 , Train acc 0.805000, Valid acc 0.704000
# Epoch 40 : Train Loss 0.172287 , Train acc 0.852000, Valid acc 0.740000
# Epoch 50 : Train Loss 0.168194 , Train acc 0.879000, Valid acc 0.774000
# Epoch 60 : Train Loss 0.164915 , Train acc 0.895000, Valid acc 0.794000
# Epoch 70 : Train Loss 0.163990 , Train acc 0.910000, Valid acc 0.808000
# Epoch 80 : Train Loss 0.161125 , Train acc 0.929000, Valid acc 0.820000
# Epoch 90 : Train Loss 0.159059 , Train acc 0.940000, Valid acc 0.832000
# Epoch 100 : Train Loss 0.158674 , Train acc 0.943000, Valid acc 0.840000
# Epoch 110 : Train Loss 0.158408 , Train acc 0.947000, Valid acc 0.838000
# Epoch 120 : Train Loss 0.157289 , Train acc 0.952000, Valid acc 0.842000
# Epoch 130 : Train Loss 0.156665 , Train acc 0.957000, Valid acc 0.840000
# Epoch 140 : Train Loss 0.155520 , Train acc 0.960000, Valid acc 0.850000
# Epoch 150 : Train Loss 0.154960 , Train acc 0.963000, Valid acc 0.856000
# Epoch 160 : Train Loss 0.154543 , Train acc 0.969000, Valid acc 0.854000
# Epoch 170 : Train Loss 0.154104 , Train acc 0.969000, Valid acc 0.852000
# Epoch 180 : Train Loss 0.152936 , Train acc 0.972000, Valid acc 0.852000
# Epoch 190 : Train Loss 0.153253 , Train acc 0.974000, Valid acc 0.848000
# Epoch 200 : Train Loss 0.152563 , Train acc 0.977000, Valid acc 0.852000
#
# dropout=0.5,   $\lambda$=0.0,   batch_norm=True
# Epoch 10 : Train Loss 0.211231 , Train acc 0.593000, Valid acc 0.508000
# Epoch 20 : Train Loss 0.190992 , Train acc 0.752000, Valid acc 0.662000
# Epoch 30 : Train Loss 0.179065 , Train acc 0.817000, Valid acc 0.730000
# Epoch 40 : Train Loss 0.173440 , Train acc 0.860000, Valid acc 0.754000
# Epoch 50 : Train Loss 0.168129 , Train acc 0.896000, Valid acc 0.780000
# Epoch 60 : Train Loss 0.166150 , Train acc 0.911000, Valid acc 0.806000
# Epoch 70 : Train Loss 0.164252 , Train acc 0.927000, Valid acc 0.826000
# Epoch 80 : Train Loss 0.161195 , Train acc 0.935000, Valid acc 0.826000
# Epoch 90 : Train Loss 0.159691 , Train acc 0.943000, Valid acc 0.832000
# Epoch 100 : Train Loss 0.158972 , Train acc 0.952000, Valid acc 0.832000
# Epoch 110 : Train Loss 0.157868 , Train acc 0.954000, Valid acc 0.832000
# Epoch 120 : Train Loss 0.157390 , Train acc 0.958000, Valid acc 0.842000
# Epoch 130 : Train Loss 0.156759 , Train acc 0.962000, Valid acc 0.844000
# Epoch 140 : Train Loss 0.155286 , Train acc 0.964000, Valid acc 0.846000
# Epoch 150 : Train Loss 0.154051 , Train acc 0.968000, Valid acc 0.846000
# Epoch 160 : Train Loss 0.154339 , Train acc 0.969000, Valid acc 0.842000
# Epoch 170 : Train Loss 0.154369 , Train acc 0.974000, Valid acc 0.846000
# Epoch 180 : Train Loss 0.153363 , Train acc 0.976000, Valid acc 0.854000
# Epoch 190 : Train Loss 0.153328 , Train acc 0.978000, Valid acc 0.848000
# Epoch 200 : Train Loss 0.153047 , Train acc 0.981000, Valid acc 0.856000
#
# dropout=0.5,   $\lambda$=0.0001,   batch_norm=False
# Epoch 10 : Train Loss 0.211285 , Train acc 0.699000, Valid acc 0.626000
# Epoch 20 : Train Loss 0.187824 , Train acc 0.781000, Valid acc 0.702000
# Epoch 30 : Train Loss 0.178060 , Train acc 0.837000, Valid acc 0.740000
# Epoch 40 : Train Loss 0.172051 , Train acc 0.864000, Valid acc 0.772000
# Epoch 50 : Train Loss 0.167966 , Train acc 0.885000, Valid acc 0.808000
# Epoch 60 : Train Loss 0.164489 , Train acc 0.904000, Valid acc 0.816000
# Epoch 70 : Train Loss 0.161915 , Train acc 0.916000, Valid acc 0.830000
# Epoch 80 : Train Loss 0.161984 , Train acc 0.927000, Valid acc 0.836000
# Epoch 90 : Train Loss 0.159923 , Train acc 0.940000, Valid acc 0.846000
# Epoch 100 : Train Loss 0.158951 , Train acc 0.948000, Valid acc 0.850000
# Epoch 110 : Train Loss 0.157100 , Train acc 0.955000, Valid acc 0.850000
# Epoch 120 : Train Loss 0.157004 , Train acc 0.964000, Valid acc 0.852000
# Epoch 130 : Train Loss 0.155780 , Train acc 0.966000, Valid acc 0.864000
# Epoch 140 : Train Loss 0.155547 , Train acc 0.967000, Valid acc 0.864000
# Epoch 150 : Train Loss 0.155233 , Train acc 0.970000, Valid acc 0.862000
# Epoch 160 : Train Loss 0.153844 , Train acc 0.974000, Valid acc 0.868000
# Epoch 170 : Train Loss 0.153744 , Train acc 0.974000, Valid acc 0.868000
# Epoch 180 : Train Loss 0.153681 , Train acc 0.974000, Valid acc 0.868000
# Epoch 190 : Train Loss 0.152446 , Train acc 0.976000, Valid acc 0.866000
# Epoch 200 : Train Loss 0.152752 , Train acc 0.977000, Valid acc 0.868000
#
# dropout=0.5,   $\lambda$=0.0001,   batch_norm=True
# Epoch 10 : Train Loss 0.209110 , Train acc 0.588000, Valid acc 0.518000
# Epoch 20 : Train Loss 0.188869 , Train acc 0.750000, Valid acc 0.682000
# Epoch 30 : Train Loss 0.178309 , Train acc 0.817000, Valid acc 0.742000
# Epoch 40 : Train Loss 0.171082 , Train acc 0.863000, Valid acc 0.766000
# Epoch 50 : Train Loss 0.167686 , Train acc 0.880000, Valid acc 0.792000
# Epoch 60 : Train Loss 0.164628 , Train acc 0.907000, Valid acc 0.810000
# Epoch 70 : Train Loss 0.162907 , Train acc 0.922000, Valid acc 0.822000
# Epoch 80 : Train Loss 0.162526 , Train acc 0.930000, Valid acc 0.828000
# Epoch 90 : Train Loss 0.160108 , Train acc 0.939000, Valid acc 0.840000
# Epoch 100 : Train Loss 0.158798 , Train acc 0.946000, Valid acc 0.844000
# Epoch 110 : Train Loss 0.157885 , Train acc 0.951000, Valid acc 0.846000
# Epoch 120 : Train Loss 0.157057 , Train acc 0.954000, Valid acc 0.844000
# Epoch 130 : Train Loss 0.156425 , Train acc 0.956000, Valid acc 0.850000
# Epoch 140 : Train Loss 0.156733 , Train acc 0.961000, Valid acc 0.850000
# Epoch 150 : Train Loss 0.154775 , Train acc 0.964000, Valid acc 0.856000
# Epoch 160 : Train Loss 0.154944 , Train acc 0.967000, Valid acc 0.860000
# Epoch 170 : Train Loss 0.154426 , Train acc 0.968000, Valid acc 0.864000
# Epoch 180 : Train Loss 0.153722 , Train acc 0.970000, Valid acc 0.858000
# Epoch 190 : Train Loss 0.154071 , Train acc 0.973000, Valid acc 0.866000
# Epoch 200 : Train Loss 0.153871 , Train acc 0.979000, Valid acc 0.860000
#
# dropout=0.5,   $\lambda$=1e-06,   batch_norm=False
# Epoch 10 : Train Loss 0.210175 , Train acc 0.586000, Valid acc 0.512000
# Epoch 20 : Train Loss 0.189975 , Train acc 0.737000, Valid acc 0.648000
# Epoch 30 : Train Loss 0.178016 , Train acc 0.824000, Valid acc 0.728000
# Epoch 40 : Train Loss 0.172170 , Train acc 0.856000, Valid acc 0.770000
# Epoch 50 : Train Loss 0.167678 , Train acc 0.884000, Valid acc 0.776000
# Epoch 60 : Train Loss 0.165012 , Train acc 0.918000, Valid acc 0.806000
# Epoch 70 : Train Loss 0.162533 , Train acc 0.922000, Valid acc 0.818000
# Epoch 80 : Train Loss 0.161464 , Train acc 0.936000, Valid acc 0.828000
# Epoch 90 : Train Loss 0.159484 , Train acc 0.941000, Valid acc 0.836000
# Epoch 100 : Train Loss 0.158425 , Train acc 0.944000, Valid acc 0.838000
# Epoch 110 : Train Loss 0.157756 , Train acc 0.951000, Valid acc 0.848000
# Epoch 120 : Train Loss 0.156530 , Train acc 0.961000, Valid acc 0.852000
# Epoch 130 : Train Loss 0.156723 , Train acc 0.965000, Valid acc 0.856000
# Epoch 140 : Train Loss 0.154989 , Train acc 0.968000, Valid acc 0.856000
# Epoch 150 : Train Loss 0.154764 , Train acc 0.970000, Valid acc 0.854000
# Epoch 160 : Train Loss 0.155194 , Train acc 0.972000, Valid acc 0.858000
# Epoch 170 : Train Loss 0.154126 , Train acc 0.973000, Valid acc 0.852000
# Epoch 180 : Train Loss 0.153072 , Train acc 0.975000, Valid acc 0.854000
# Epoch 190 : Train Loss 0.153812 , Train acc 0.975000, Valid acc 0.852000
# Epoch 200 : Train Loss 0.152406 , Train acc 0.976000, Valid acc 0.856000
#
# dropout=0.5,   $\lambda$=1e-06,   batch_norm=True
# Epoch 10 : Train Loss 0.210039 , Train acc 0.611000, Valid acc 0.508000
# Epoch 20 : Train Loss 0.189913 , Train acc 0.731000, Valid acc 0.654000
# Epoch 30 : Train Loss 0.179733 , Train acc 0.779000, Valid acc 0.706000
# Epoch 40 : Train Loss 0.173210 , Train acc 0.822000, Valid acc 0.736000
# Epoch 50 : Train Loss 0.169959 , Train acc 0.866000, Valid acc 0.764000
# Epoch 60 : Train Loss 0.167108 , Train acc 0.897000, Valid acc 0.798000
# Epoch 70 : Train Loss 0.164381 , Train acc 0.915000, Valid acc 0.812000
# Epoch 80 : Train Loss 0.162103 , Train acc 0.926000, Valid acc 0.830000
# Epoch 90 : Train Loss 0.161073 , Train acc 0.933000, Valid acc 0.838000
# Epoch 100 : Train Loss 0.158917 , Train acc 0.935000, Valid acc 0.846000
# Epoch 110 : Train Loss 0.158267 , Train acc 0.947000, Valid acc 0.842000
# Epoch 120 : Train Loss 0.157862 , Train acc 0.953000, Valid acc 0.846000
# Epoch 130 : Train Loss 0.156086 , Train acc 0.960000, Valid acc 0.850000
# Epoch 140 : Train Loss 0.155193 , Train acc 0.965000, Valid acc 0.854000
# Epoch 150 : Train Loss 0.155424 , Train acc 0.969000, Valid acc 0.850000
# Epoch 160 : Train Loss 0.153995 , Train acc 0.971000, Valid acc 0.856000
# Epoch 170 : Train Loss 0.153131 , Train acc 0.973000, Valid acc 0.856000
# Epoch 180 : Train Loss 0.153758 , Train acc 0.978000, Valid acc 0.858000
# Epoch 190 : Train Loss 0.152762 , Train acc 0.978000, Valid acc 0.856000
# Epoch 200 : Train Loss 0.152933 , Train acc 0.978000, Valid acc 0.856000
#
# dropout=0.5,   $\lambda$=1e-08,   batch_norm=False
# Epoch 10 : Train Loss 0.211229 , Train acc 0.564000, Valid acc 0.460000
# Epoch 20 : Train Loss 0.190348 , Train acc 0.763000, Valid acc 0.680000
# Epoch 30 : Train Loss 0.178476 , Train acc 0.832000, Valid acc 0.756000
# Epoch 40 : Train Loss 0.172531 , Train acc 0.869000, Valid acc 0.780000
# Epoch 50 : Train Loss 0.168940 , Train acc 0.890000, Valid acc 0.792000
# Epoch 60 : Train Loss 0.166191 , Train acc 0.903000, Valid acc 0.796000
# Epoch 70 : Train Loss 0.162048 , Train acc 0.923000, Valid acc 0.816000
# Epoch 80 : Train Loss 0.161694 , Train acc 0.936000, Valid acc 0.830000
# Epoch 90 : Train Loss 0.159320 , Train acc 0.942000, Valid acc 0.832000
# Epoch 100 : Train Loss 0.158510 , Train acc 0.948000, Valid acc 0.840000
# Epoch 110 : Train Loss 0.156994 , Train acc 0.951000, Valid acc 0.844000
# Epoch 120 : Train Loss 0.156735 , Train acc 0.959000, Valid acc 0.846000
# Epoch 130 : Train Loss 0.157101 , Train acc 0.962000, Valid acc 0.848000
# Epoch 140 : Train Loss 0.155470 , Train acc 0.964000, Valid acc 0.850000
# Epoch 150 : Train Loss 0.155296 , Train acc 0.964000, Valid acc 0.852000
# Epoch 160 : Train Loss 0.154670 , Train acc 0.965000, Valid acc 0.854000
# Epoch 170 : Train Loss 0.153828 , Train acc 0.971000, Valid acc 0.856000
# Epoch 180 : Train Loss 0.153290 , Train acc 0.974000, Valid acc 0.858000
# Epoch 190 : Train Loss 0.153501 , Train acc 0.973000, Valid acc 0.862000
# Epoch 200 : Train Loss 0.153433 , Train acc 0.976000, Valid acc 0.860000
#
# dropout=0.5,   $\lambda$=1e-08,   batch_norm=True
# Epoch 10 : Train Loss 0.210871 , Train acc 0.603000, Valid acc 0.500000
# Epoch 20 : Train Loss 0.190820 , Train acc 0.768000, Valid acc 0.660000
# Epoch 30 : Train Loss 0.176999 , Train acc 0.829000, Valid acc 0.714000
# Epoch 40 : Train Loss 0.171569 , Train acc 0.862000, Valid acc 0.760000
# Epoch 50 : Train Loss 0.168010 , Train acc 0.891000, Valid acc 0.792000
# Epoch 60 : Train Loss 0.164213 , Train acc 0.906000, Valid acc 0.798000
# Epoch 70 : Train Loss 0.164066 , Train acc 0.919000, Valid acc 0.820000
# Epoch 80 : Train Loss 0.160640 , Train acc 0.929000, Valid acc 0.830000
# Epoch 90 : Train Loss 0.159926 , Train acc 0.938000, Valid acc 0.840000
# Epoch 100 : Train Loss 0.158578 , Train acc 0.948000, Valid acc 0.842000
# Epoch 110 : Train Loss 0.156935 , Train acc 0.956000, Valid acc 0.842000
# Epoch 120 : Train Loss 0.156422 , Train acc 0.961000, Valid acc 0.852000
# Epoch 130 : Train Loss 0.155509 , Train acc 0.964000, Valid acc 0.848000
# Epoch 140 : Train Loss 0.155344 , Train acc 0.966000, Valid acc 0.848000
# Epoch 150 : Train Loss 0.155678 , Train acc 0.969000, Valid acc 0.856000
# Epoch 160 : Train Loss 0.154126 , Train acc 0.972000, Valid acc 0.854000
# Epoch 170 : Train Loss 0.154333 , Train acc 0.975000, Valid acc 0.850000
# Epoch 180 : Train Loss 0.154017 , Train acc 0.978000, Valid acc 0.848000
# Epoch 190 : Train Loss 0.153205 , Train acc 0.979000, Valid acc 0.854000
# Epoch 200 : Train Loss 0.153149 , Train acc 0.979000, Valid acc 0.854000

# %%
dropout_acc = {}
lambda_acc = {}
batch_norm = {}

for dropout_val, lambdak, batch_norm_val in mynets:
    net = mynets[dropout_val, lambdak, batch_norm_val]
    print(f"dropout={dropout_val},   lambda={lambdak},   batch_norm={batch_norm_val}:   {np.mean(net.valid_acc[-10:])}")
# Out:
# dropout=0.0,   lambda=0.0,   batch_norm=False:   0.8131999999999999
# dropout=0.0,   lambda=0.0,   batch_norm=True:   0.82
# dropout=0.0,   lambda=0.0001,   batch_norm=False:   0.8348000000000001
# dropout=0.0,   lambda=0.0001,   batch_norm=True:   0.8455999999999999
# dropout=0.0,   lambda=1e-06,   batch_norm=False:   0.8240000000000001
# dropout=0.0,   lambda=1e-06,   batch_norm=True:   0.8408
# dropout=0.0,   lambda=1e-08,   batch_norm=False:   0.827
# dropout=0.0,   lambda=1e-08,   batch_norm=True:   0.8135999999999999
# dropout=0.1,   lambda=0.0,   batch_norm=False:   0.8328
# dropout=0.1,   lambda=0.0,   batch_norm=True:   0.8522000000000001
# dropout=0.1,   lambda=0.0001,   batch_norm=False:   0.8576
# dropout=0.1,   lambda=0.0001,   batch_norm=True:   0.8577999999999999
# dropout=0.1,   lambda=1e-06,   batch_norm=False:   0.8511999999999998
# dropout=0.1,   lambda=1e-06,   batch_norm=True:   0.8654
# dropout=0.1,   lambda=1e-08,   batch_norm=False:   0.8431999999999998
# dropout=0.1,   lambda=1e-08,   batch_norm=True:   0.8446
# dropout=0.3,   lambda=0.0,   batch_norm=False:   0.8638
# dropout=0.3,   lambda=0.0,   batch_norm=True:   0.8568
# dropout=0.3,   lambda=0.0001,   batch_norm=False:   0.869
# dropout=0.3,   lambda=0.0001,   batch_norm=True:   0.8699999999999999
# dropout=0.3,   lambda=1e-06,   batch_norm=False:   0.8562
# dropout=0.3,   lambda=1e-06,   batch_norm=True:   0.8523999999999999
# dropout=0.3,   lambda=1e-08,   batch_norm=False:   0.8634000000000001
# dropout=0.3,   lambda=1e-08,   batch_norm=True:   0.8699999999999999
# dropout=0.5,   lambda=0.0,   batch_norm=False:   0.8512000000000001
# dropout=0.5,   lambda=0.0,   batch_norm=True:   0.8518000000000001
# dropout=0.5,   lambda=0.0001,   batch_norm=False:   0.8654
# dropout=0.5,   lambda=0.0001,   batch_norm=True:   0.861
# dropout=0.5,   lambda=1e-06,   batch_norm=False:   0.853
# dropout=0.5,   lambda=1e-06,   batch_norm=True:   0.8578000000000001
# dropout=0.5,   lambda=1e-08,   batch_norm=False:   0.8606
# dropout=0.5,   lambda=1e-08,   batch_norm=True:   0.853

# %% [markdown]
# You are done for now. [Good job.](https://media1.tenor.com/images/0fd559b07f2174f9b8b7dbde7c5a67ca/tenor.gif)

# %% [markdown]
# # Exercise 1 from chapter 3:
# * Verify that $\sigma'(z)=\sigma(z)(1-\sigma(z))$
#
# \\
# # Answer:
# the $\text{sigmoid}$ function, $\sigma(z)$, is given by:
# $$\sigma(z)=\frac1{1+\exp(-z)}$$
#
# Differentiating using the chain rule yields
# $$
# \begin{align*}
# %
# \sigma'(z)&= -\left(\frac1{1+\exp(-z)}\right)^2\cdot (-\exp(-z))\\
# %
# &= \left(\frac1{1+\exp(-z)}\right)^2\cdot \exp(-z)\\
# %
# &= \sigma(z)\cdot\frac{\exp(-z)}{1+\exp(-z)}\\
# %
# &= \sigma(z)\cdot\frac{-1+1+\exp(-z)}{1+\exp(-z)}\\
# %
# &= \sigma(z)\cdot\left(\frac{-1}{1+\exp(-z)}+\frac{1+\exp(-z)}{1+\exp(-z)}\right)\\
# %
# &= \sigma(z)\cdot\left(-\sigma(z)+1\right)\\
# %
# %
# %
# \end{align*}
# $$
